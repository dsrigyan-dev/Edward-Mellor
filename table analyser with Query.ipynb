# %% [markdown]
# # Data & Details

# %% [markdown]
# ## Defulat folder setup

# %%
import os

# Change the current working directory
os.chdir('C:/Users/srigd/Desktop/Project/Python/General Details')

# Now, when you open a file without specifying a full path, Python looks in the current working directory
with open('another_file.txt', 'w') as f:
    f.write('This file is saved in the specified default directory.')

# %% [markdown]
# ## Salesforce Connection

# %%
import requests
import pandas as pd
from simple_salesforce import Salesforce
import keyring

# Retrieve your credentials
username = keyring.get_password("salesforce", "username")
password = keyring.get_password("salesforce", "password")
security_token = keyring.get_password("salesforce", "security_token")
consumer_key = keyring.get_password("salesforce", "consumer_key")
consumer_secret = keyring.get_password("salesforce", "consumer_secret")

# Step 1: Obtain OAuth 2.0 token
token_url = "https://login.salesforce.com/services/oauth2/token"
payload = {
    'grant_type': 'password',
    'client_id': consumer_key,
    'client_secret': consumer_secret,
    'username': username,
    'password': password + security_token
}
response = requests.post(token_url, data=payload)
response.raise_for_status()  # Check if the request was successful

# Extract access token from the response
access_token = response.json().get('access_token')
instance_url = response.json().get('instance_url')

# Step 2: Authenticate to Salesforce using the access token
sf = Salesforce(instance_url=instance_url, session_id=access_token)

# %% [markdown]
# ## Metadata extractor

# %%
def get_salesforce_metadata(sf):
    metadata = []
    # Get all objects
    objects = sf.describe()["sobjects"]
    
    for obj in objects:
        obj_name = obj["name"]
        fields = sf.__getattr__(obj_name).describe()["fields"]
        
        for field in fields:
            field_metadata = {
                "object": obj_name,
                "field": field["name"],
                "type": field["type"],
                "length": field.get("length"),
                "relationship": field.get("relationshipName"),
                "related_to": field.get("referenceTo")
            }
            metadata.append(field_metadata)
    
    return pd.DataFrame(metadata)

metadata_df = get_salesforce_metadata(sf)

# %%
metadata_df.to_excel('metadata_df.xlsx')

# %% [markdown]
# ## Calculate Data Completeness

# %%
from simple_salesforce import Salesforce, SalesforceMalformedRequest
import pandas as pd
import time

def calculate_data_completeness(sf, metadata_df, max_fields_per_object=10):
    completeness = []
    
    for obj in metadata_df["object"].unique():
        start_time = time.time()
        try:
            query = f"SELECT COUNT() FROM {obj}"
            total_records = sf.query(query)["totalSize"]
        except (SalesforceMalformedRequest, Exception) as e:
            # Skip objects that do not support querying
            print(f"Skipping {obj} due to error: {e}")
            continue
        
        fields_processed = 0
        for field in metadata_df[metadata_df["object"] == obj]["field"]:
            if fields_processed >= max_fields_per_object:
                break
            try:
                # Use a different approach to count non-null values
                query = f"SELECT {field} FROM {obj} WHERE {field} != null"
                filled_records = sf.query(query)["totalSize"]
                
                completeness.append({
                    "object": obj,
                    "field": field,
                    "total_records": total_records,
                    "filled_records": filled_records,
                    "completeness_percentage": (filled_records / total_records) * 100 if total_records else 0
                })
                fields_processed += 1
                print(f"Processed field {field} in object {obj}")
            except (SalesforceMalformedRequest, Exception) as e:
                # Skip fields that cause errors
                print(f"Skipping field {field} in object {obj} due to error: {e}")
                continue
        
        end_time = time.time()
        print(f"Processed object {obj} in {end_time - start_time:.2f} seconds")

    return pd.DataFrame(completeness)

# Assuming you have already connected to Salesforce and retrieved metadata_df
completeness_df = calculate_data_completeness(sf, metadata_df, max_fields_per_object=5)

# import ace_tools as tools
# tools.display_dataframe_to_user(name="Data Completeness", dataframe=completeness_df)
# Out:
# Skipping ACTIVITES_EMv2__ChangeEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+ACTIVITES_EMv2__ChangeEvent. Response content: [{'message': 'entity type ACTIVITES_EMv2__ChangeEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object ACTIVITES_EMv2__History
# Processed field IsDeleted in object ACTIVITES_EMv2__History
# Processed field ParentId in object ACTIVITES_EMv2__History
# Processed field CreatedById in object ACTIVITES_EMv2__History
# Processed field CreatedDate in object ACTIVITES_EMv2__History
# Processed object ACTIVITES_EMv2__History in 0.72 seconds
# Processed field Id in object ACTIVITES_EMv2__c
# Processed field IsDeleted in object ACTIVITES_EMv2__c
# Processed field Name in object ACTIVITES_EMv2__c
# Processed field CurrencyIsoCode in object ACTIVITES_EMv2__c
# Processed field CreatedDate in object ACTIVITES_EMv2__c
# Processed object ACTIVITES_EMv2__c in 0.75 seconds
# Skipping ACTIVITY_Category__ChangeEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+ACTIVITY_Category__ChangeEvent. Response content: [{'message': 'entity type ACTIVITY_Category__ChangeEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object ACTIVITY_Category__Share
# Processed field ParentId in object ACTIVITY_Category__Share
# Processed field UserOrGroupId in object ACTIVITY_Category__Share
# Processed field AccessLevel in object ACTIVITY_Category__Share
# Processed field RowCause in object ACTIVITY_Category__Share
# Processed object ACTIVITY_Category__Share in 0.30 seconds
# Processed field Id in object ACTIVITY_Category__c
# Processed field OwnerId in object ACTIVITY_Category__c
# Processed field IsDeleted in object ACTIVITY_Category__c
# Processed field Name in object ACTIVITY_Category__c
# Processed field CurrencyIsoCode in object ACTIVITY_Category__c
# Processed object ACTIVITY_Category__c in 0.29 seconds
# Skipping ACTIVITY_Template_EMv2__ChangeEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+ACTIVITY_Template_EMv2__ChangeEvent. Response content: [{'message': 'entity type ACTIVITY_Template_EMv2__ChangeEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object ACTIVITY_Template_EMv2__Share
# Processed field ParentId in object ACTIVITY_Template_EMv2__Share
# Processed field UserOrGroupId in object ACTIVITY_Template_EMv2__Share
# Processed field AccessLevel in object ACTIVITY_Template_EMv2__Share
# Processed field RowCause in object ACTIVITY_Template_EMv2__Share
# Processed object ACTIVITY_Template_EMv2__Share in 0.30 seconds
# Processed field Id in object ACTIVITY_Template_EMv2__c
# Processed field OwnerId in object ACTIVITY_Template_EMv2__c
# Processed field IsDeleted in object ACTIVITY_Template_EMv2__c
# Processed field Name in object ACTIVITY_Template_EMv2__c
# Processed field CurrencyIsoCode in object ACTIVITY_Template_EMv2__c
# Processed object ACTIVITY_Template_EMv2__c in 0.33 seconds
# Processed field Id in object AIApplication
# Processed field IsDeleted in object AIApplication
# Processed field DeveloperName in object AIApplication
# Processed field Language in object AIApplication
# Processed field MasterLabel in object AIApplication
# Processed object AIApplication in 0.32 seconds
# Processed field Id in object AIApplicationConfig
# Processed field IsDeleted in object AIApplicationConfig
# Processed field DeveloperName in object AIApplicationConfig
# Processed field Language in object AIApplicationConfig
# Processed field MasterLabel in object AIApplicationConfig
# Processed object AIApplicationConfig in 0.39 seconds
# Processed field Id in object AIInsightAction
# Processed field IsDeleted in object AIInsightAction
# Processed field Name in object AIInsightAction
# Processed field CreatedDate in object AIInsightAction
# Processed field CreatedById in object AIInsightAction
# Processed object AIInsightAction in 0.37 seconds
# Processed field Id in object AIInsightFeedback
# Processed field IsDeleted in object AIInsightFeedback
# Processed field Name in object AIInsightFeedback
# Processed field CreatedDate in object AIInsightFeedback
# Processed field CreatedById in object AIInsightFeedback
# Processed object AIInsightFeedback in 0.30 seconds
# Processed field Id in object AIInsightReason
# Processed field IsDeleted in object AIInsightReason
# Processed field Name in object AIInsightReason
# Processed field CreatedDate in object AIInsightReason
# Processed field CreatedById in object AIInsightReason
# Processed object AIInsightReason in 0.29 seconds
# Processed field Id in object AIInsightValue
# Processed field IsDeleted in object AIInsightValue
# Processed field Name in object AIInsightValue
# Processed field CreatedDate in object AIInsightValue
# Processed field CreatedById in object AIInsightValue
# Processed object AIInsightValue in 0.29 seconds
# Skipping AIPredictionEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+AIPredictionEvent. Response content: [{'message': 'entity type AIPredictionEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object AIRecordInsight
# Processed field IsDeleted in object AIRecordInsight
# Processed field Name in object AIRecordInsight
# Processed field CreatedDate in object AIRecordInsight
# Processed field CreatedById in object AIRecordInsight
# Processed object AIRecordInsight in 0.35 seconds
# Skipping API_Update_Overview__ChangeEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+API_Update_Overview__ChangeEvent. Response content: [{'message': 'entity type API_Update_Overview__ChangeEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object API_Update_Overview__Share
# Processed field ParentId in object API_Update_Overview__Share
# Processed field UserOrGroupId in object API_Update_Overview__Share
# Processed field AccessLevel in object API_Update_Overview__Share
# Processed field RowCause in object API_Update_Overview__Share
# Processed object API_Update_Overview__Share in 0.32 seconds
# Processed field Id in object API_Update_Overview__c
# Processed field OwnerId in object API_Update_Overview__c
# Processed field IsDeleted in object API_Update_Overview__c
# Processed field Name in object API_Update_Overview__c
# Processed field CurrencyIsoCode in object API_Update_Overview__c
# Processed object API_Update_Overview__c in 0.37 seconds
# Processed field Id in object AcceptedEventRelation
# Processed field RelationId in object AcceptedEventRelation
# Processed field EventId in object AcceptedEventRelation
# Processed field AccountId in object AcceptedEventRelation
# Processed field RespondedDate in object AcceptedEventRelation
# Processed object AcceptedEventRelation in 26.47 seconds
# Processed field Id in object Account
# Processed field IsDeleted in object Account
# Processed field MasterRecordId in object Account
# Processed field Name in object Account
# Processed field Type in object Account
# Processed object Account in 9.98 seconds
# Processed field Id in object AccountBrand
# Processed field OwnerId in object AccountBrand
# Processed field IsDeleted in object AccountBrand
# Processed field Name in object AccountBrand
# Processed field CurrencyIsoCode in object AccountBrand
# Processed object AccountBrand in 0.36 seconds
# Processed field Id in object AccountBrandShare
# Processed field ParentId in object AccountBrandShare
# Processed field UserOrGroupId in object AccountBrandShare
# Processed field AccessLevel in object AccountBrandShare
# Processed field RowCause in object AccountBrandShare
# Processed object AccountBrandShare in 0.32 seconds
# Skipping AccountChangeEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+AccountChangeEvent. Response content: [{'message': 'entity type AccountChangeEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object AccountContactRelation
# Processed field AccountId in object AccountContactRelation
# Processed field ContactId in object AccountContactRelation
# Processed field Roles in object AccountContactRelation
# Processed field IsDirect in object AccountContactRelation
# Processed object AccountContactRelation in 5.90 seconds
# Skipping AccountContactRelationChangeEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+AccountContactRelationChangeEvent. Response content: [{'message': 'entity type AccountContactRelationChangeEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object AccountContactRole
# Processed field IsDeleted in object AccountContactRole
# Processed field CreatedDate in object AccountContactRole
# Processed field CreatedById in object AccountContactRole
# Processed field LastModifiedDate in object AccountContactRole
# Processed object AccountContactRole in 0.28 seconds
# Skipping AccountContactRoleChangeEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+AccountContactRoleChangeEvent. Response content: [{'message': 'entity type AccountContactRoleChangeEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object AccountFeed
# Processed field ParentId in object AccountFeed
# Processed field Type in object AccountFeed
# Processed field CreatedById in object AccountFeed
# Processed field CreatedDate in object AccountFeed
# Processed object AccountFeed in 1.93 seconds
# Processed field Id in object AccountHistory
# Processed field IsDeleted in object AccountHistory
# Processed field AccountId in object AccountHistory
# Processed field CreatedById in object AccountHistory
# Processed field CreatedDate in object AccountHistory
# Processed object AccountHistory in 30.25 seconds
# Processed field Id in object AccountParticipant
# Processed field IsDeleted in object AccountParticipant
# Processed field Name in object AccountParticipant
# Processed field CurrencyIsoCode in object AccountParticipant
# Processed field CreatedDate in object AccountParticipant
# Processed object AccountParticipant in 0.44 seconds
# Processed field Id in object AccountParticipantFeed
# Processed field ParentId in object AccountParticipantFeed
# Processed field Type in object AccountParticipantFeed
# Processed field CreatedById in object AccountParticipantFeed
# Processed field CreatedDate in object AccountParticipantFeed
# Processed object AccountParticipantFeed in 0.37 seconds
# Processed field Id in object AccountParticipantHistory
# Processed field IsDeleted in object AccountParticipantHistory
# Processed field AccountParticipantId in object AccountParticipantHistory
# Processed field CreatedById in object AccountParticipantHistory
# Processed field CreatedDate in object AccountParticipantHistory
# Processed object AccountParticipantHistory in 0.37 seconds
# Processed field Id in object AccountPartner
# Processed field AccountFromId in object AccountPartner
# Processed field AccountToId in object AccountPartner
# Processed field OpportunityId in object AccountPartner
# Processed field Role in object AccountPartner
# Processed object AccountPartner in 0.35 seconds
# Processed field Id in object AccountShare
# Processed field AccountId in object AccountShare
# Processed field UserOrGroupId in object AccountShare
# Processed field AccountAccessLevel in object AccountShare
# Processed field OpportunityAccessLevel in object AccountShare
# Processed object AccountShare in 92.84 seconds
# Processed field Id in object ActionLinkGroupTemplate
# Processed field IsDeleted in object ActionLinkGroupTemplate
# Processed field DeveloperName in object ActionLinkGroupTemplate
# Processed field Language in object ActionLinkGroupTemplate
# Processed field MasterLabel in object ActionLinkGroupTemplate
# Processed object ActionLinkGroupTemplate in 0.31 seconds
# Processed field Id in object ActionLinkTemplate
# Processed field IsDeleted in object ActionLinkTemplate
# Processed field CreatedDate in object ActionLinkTemplate
# Processed field CreatedById in object ActionLinkTemplate
# Processed field LastModifiedDate in object ActionLinkTemplate
# Processed object ActionLinkTemplate in 0.38 seconds
# Processed field Id in object ActionPlan
# Processed field OwnerId in object ActionPlan
# Processed field IsDeleted in object ActionPlan
# Processed field Name in object ActionPlan
# Processed field CurrencyIsoCode in object ActionPlan
# Processed object ActionPlan in 0.37 seconds
# Processed field Id in object ActionPlanFeed
# Processed field ParentId in object ActionPlanFeed
# Processed field Type in object ActionPlanFeed
# Processed field CreatedById in object ActionPlanFeed
# Processed field CreatedDate in object ActionPlanFeed
# Processed object ActionPlanFeed in 0.35 seconds
# Processed field Id in object ActionPlanItem
# Processed field IsDeleted in object ActionPlanItem
# Processed field Name in object ActionPlanItem
# Processed field CurrencyIsoCode in object ActionPlanItem
# Processed field CreatedDate in object ActionPlanItem
# Processed object ActionPlanItem in 0.32 seconds
# Processed field Id in object ActionPlanItemDependency
# Processed field IsDeleted in object ActionPlanItemDependency
# Processed field Name in object ActionPlanItemDependency
# Processed field CurrencyIsoCode in object ActionPlanItemDependency
# Processed field CreatedDate in object ActionPlanItemDependency
# Processed object ActionPlanItemDependency in 0.35 seconds
# Processed field Id in object ActionPlanShare
# Processed field ParentId in object ActionPlanShare
# Processed field UserOrGroupId in object ActionPlanShare
# Processed field AccessLevel in object ActionPlanShare
# Processed field RowCause in object ActionPlanShare
# Processed object ActionPlanShare in 0.31 seconds
# Processed field Id in object ActionPlanTemplate
# Processed field OwnerId in object ActionPlanTemplate
# Processed field IsDeleted in object ActionPlanTemplate
# Processed field Name in object ActionPlanTemplate
# Processed field CurrencyIsoCode in object ActionPlanTemplate
# Processed object ActionPlanTemplate in 0.34 seconds
# Processed field Id in object ActionPlanTemplateItem
# Processed field IsDeleted in object ActionPlanTemplateItem
# Processed field Name in object ActionPlanTemplateItem
# Processed field CurrencyIsoCode in object ActionPlanTemplateItem
# Processed field CreatedDate in object ActionPlanTemplateItem
# Processed object ActionPlanTemplateItem in 0.32 seconds
# Processed field Id in object ActionPlanTemplateItemValue
# Processed field IsDeleted in object ActionPlanTemplateItemValue
# Processed field Name in object ActionPlanTemplateItemValue
# Processed field CurrencyIsoCode in object ActionPlanTemplateItemValue
# Processed field CreatedDate in object ActionPlanTemplateItemValue
# Processed object ActionPlanTemplateItemValue in 0.40 seconds
# Processed field Id in object ActionPlanTemplateShare
# Processed field ParentId in object ActionPlanTemplateShare
# Processed field UserOrGroupId in object ActionPlanTemplateShare
# Processed field AccessLevel in object ActionPlanTemplateShare
# Processed field RowCause in object ActionPlanTemplateShare
# Processed object ActionPlanTemplateShare in 0.31 seconds
# Processed field Id in object ActionPlanTemplateVersion
# Processed field IsDeleted in object ActionPlanTemplateVersion
# Processed field Name in object ActionPlanTemplateVersion
# Processed field CurrencyIsoCode in object ActionPlanTemplateVersion
# Processed field CreatedDate in object ActionPlanTemplateVersion
# Processed object ActionPlanTemplateVersion in 0.38 seconds
# Processed field Id in object ActionPlanTmplPkgConfig
# Processed field IsDeleted in object ActionPlanTmplPkgConfig
# Processed field DeveloperName in object ActionPlanTmplPkgConfig
# Processed field Language in object ActionPlanTmplPkgConfig
# Processed field MasterLabel in object ActionPlanTmplPkgConfig
# Processed object ActionPlanTmplPkgConfig in 0.39 seconds
# Processed field Id in object ActionPlnTmplItmDependency
# Processed field IsDeleted in object ActionPlnTmplItmDependency
# Processed field Name in object ActionPlnTmplItmDependency
# Processed field CurrencyIsoCode in object ActionPlnTmplItmDependency
# Processed field CreatedDate in object ActionPlnTmplItmDependency
# Processed object ActionPlnTmplItmDependency in 0.34 seconds
# Processed field Id in object ActiveFeatureLicenseMetric
# Processed field MetricsDate in object ActiveFeatureLicenseMetric
# Processed field FeatureType in object ActiveFeatureLicenseMetric
# Processed field SystemModstamp in object ActiveFeatureLicenseMetric
# Processed field AssignedUserCount in object ActiveFeatureLicenseMetric
# Processed object ActiveFeatureLicenseMetric in 0.39 seconds
# Processed field Id in object ActivePermSetLicenseMetric
# Processed field MetricsDate in object ActivePermSetLicenseMetric
# Processed field PermissionSetLicenseId in object ActivePermSetLicenseMetric
# Processed field SystemModstamp in object ActivePermSetLicenseMetric
# Processed field AssignedUserCount in object ActivePermSetLicenseMetric
# Processed object ActivePermSetLicenseMetric in 0.91 seconds
# Processed field Id in object ActiveProfileMetric
# Processed field MetricsDate in object ActiveProfileMetric
# Processed field UserLicenseId in object ActiveProfileMetric
# Processed field ProfileId in object ActiveProfileMetric
# Processed field SystemModstamp in object ActiveProfileMetric
# Processed object ActiveProfileMetric in 0.81 seconds
# Processed field Id in object ActiveScratchOrg
# Processed field OwnerId in object ActiveScratchOrg
# Processed field IsDeleted in object ActiveScratchOrg
# Processed field Name in object ActiveScratchOrg
# Processed field CurrencyIsoCode in object ActiveScratchOrg
# Processed object ActiveScratchOrg in 0.37 seconds
# Processed field Id in object ActiveScratchOrgFeed
# Processed field ParentId in object ActiveScratchOrgFeed
# Processed field Type in object ActiveScratchOrgFeed
# Processed field CreatedById in object ActiveScratchOrgFeed
# Processed field CreatedDate in object ActiveScratchOrgFeed
# Processed object ActiveScratchOrgFeed in 0.33 seconds
# Processed field Id in object ActiveScratchOrgHistory
# Processed field IsDeleted in object ActiveScratchOrgHistory
# Processed field ActiveScratchOrgId in object ActiveScratchOrgHistory
# Processed field CreatedById in object ActiveScratchOrgHistory
# Processed field CreatedDate in object ActiveScratchOrgHistory
# Processed object ActiveScratchOrgHistory in 0.87 seconds
# Processed field Id in object ActiveScratchOrgShare
# Processed field ParentId in object ActiveScratchOrgShare
# Processed field UserOrGroupId in object ActiveScratchOrgShare
# Processed field AccessLevel in object ActiveScratchOrgShare
# Processed field RowCause in object ActiveScratchOrgShare
# Processed object ActiveScratchOrgShare in 0.40 seconds
# Skipping ActivityFieldHistory due to error: Error Code 500. Response content: [{'message': 'An unexpected error occurred. Please include this ErrorId if you contact support: 383584860-373917 (2119471724)', 'errorCode': 'UNKNOWN_EXCEPTION'}]
# Skipping ActivityHistory due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+ActivityHistory. Response content: [{'message': 'entity type ActivityHistory does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object ActivityUsrConnectionStatus
# Skipping field ExternalId in object ActivityUsrConnectionStatus due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+ExternalId+FROM+ActivityUsrConnectionStatus+WHERE+ExternalId+%21%3D+null. Response content: [{'message': 'query operation not supported', 'errorCode': 'EXTERNAL_OBJECT_UNSUPPORTED_EXCEPTION'}]
# Skipping field UserId in object ActivityUsrConnectionStatus due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+UserId+FROM+ActivityUsrConnectionStatus+WHERE+UserId+%21%3D+null. Response content: [{'message': 'query operation not supported', 'errorCode': 'EXTERNAL_OBJECT_UNSUPPORTED_EXCEPTION'}]
# Processed field UserName in object ActivityUsrConnectionStatus
# Skipping field ConfigurationName in object ActivityUsrConnectionStatus due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+ConfigurationName+FROM+ActivityUsrConnectionStatus+WHERE+ConfigurationName+%21%3D+null. Response content: [{'message': 'query operation not supported', 'errorCode': 'EXTERNAL_OBJECT_UNSUPPORTED_EXCEPTION'}]
# Skipping field EmailAddress in object ActivityUsrConnectionStatus due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+EmailAddress+FROM+ActivityUsrConnectionStatus+WHERE+EmailAddress+%21%3D+null. Response content: [{'message': 'query operation not supported', 'errorCode': 'EXTERNAL_OBJECT_UNSUPPORTED_EXCEPTION'}]
# Skipping field ConnectivityStatus in object ActivityUsrConnectionStatus due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+ConnectivityStatus+FROM+ActivityUsrConnectionStatus+WHERE+ConnectivityStatus+%21%3D+null. Response content: [{'message': 'incorrect SalesforceIqDataSourceStatus enum value', 'errorCode': 'EXTERNAL_OBJECT_UNSUPPORTED_EXCEPTION'}]
# Skipping field RecommendedActionTitle in object ActivityUsrConnectionStatus due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+RecommendedActionTitle+FROM+ActivityUsrConnectionStatus+WHERE+RecommendedActionTitle+%21%3D+null. Response content: [{'message': 'query operation not supported', 'errorCode': 'EXTERNAL_OBJECT_UNSUPPORTED_EXCEPTION'}]
# Skipping field RecommendedActionDescription in object ActivityUsrConnectionStatus due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+RecommendedActionDescription+FROM+ActivityUsrConnectionStatus+WHERE+RecommendedActionDescription+%21%3D+null. Response content: [{'message': 'query operation not supported', 'errorCode': 'EXTERNAL_OBJECT_UNSUPPORTED_EXCEPTION'}]
# Processed field IsTermsOfServiceAccepted in object ActivityUsrConnectionStatus
# Processed field GlobalOauthTermsState in object ActivityUsrConnectionStatus
# Skipping field ContactsSynced in object ActivityUsrConnectionStatus due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+ContactsSynced+FROM+ActivityUsrConnectionStatus+WHERE+ContactsSynced+%21%3D+null. Response content: [{'message': 'query operation not supported', 'errorCode': 'EXTERNAL_OBJECT_UNSUPPORTED_EXCEPTION'}]
# Skipping field EventsSynced in object ActivityUsrConnectionStatus due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+EventsSynced+FROM+ActivityUsrConnectionStatus+WHERE+EventsSynced+%21%3D+null. Response content: [{'message': 'query operation not supported', 'errorCode': 'EXTERNAL_OBJECT_UNSUPPORTED_EXCEPTION'}]
# Skipping field UserOnboardingStatus in object ActivityUsrConnectionStatus due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+UserOnboardingStatus+FROM+ActivityUsrConnectionStatus+WHERE+UserOnboardingStatus+%21%3D+null. Response content: [{'message': 'query operation not supported', 'errorCode': 'EXTERNAL_OBJECT_UNSUPPORTED_EXCEPTION'}]
# Processed object ActivityUsrConnectionStatus in 3.07 seconds
# Skipping Activity_Rule__ChangeEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+Activity_Rule__ChangeEvent. Response content: [{'message': 'entity type Activity_Rule__ChangeEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object Activity_Rule__c
# Processed field IsDeleted in object Activity_Rule__c
# Processed field Name in object Activity_Rule__c
# Processed field CurrencyIsoCode in object Activity_Rule__c
# Processed field CreatedDate in object Activity_Rule__c
# Processed object Activity_Rule__c in 0.34 seconds
# Processed field Id in object AdditionalNumber
# Processed field IsDeleted in object AdditionalNumber
# Processed field CallCenterId in object AdditionalNumber
# Processed field Name in object AdditionalNumber
# Processed field Description in object AdditionalNumber
# Processed object AdditionalNumber in 0.33 seconds
# Processed field Id in object Address
# Processed field IsDeleted in object Address
# Processed field Name in object Address
# Processed field CurrencyIsoCode in object Address
# Processed field CreatedDate in object Address
# Processed object Address in 0.31 seconds
# Skipping AggregateResult due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+AggregateResult. Response content: [{'message': 'entity type AggregateResult does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object Announcement
# Processed field IsDeleted in object Announcement
# Processed field CreatedDate in object Announcement
# Processed field CreatedById in object Announcement
# Processed field LastModifiedDate in object Announcement
# Processed object Announcement in 0.49 seconds
# Processed field Id in object ApexClass
# Processed field NamespacePrefix in object ApexClass
# Processed field Name in object ApexClass
# Processed field ApiVersion in object ApexClass
# Processed field Status in object ApexClass
# Processed object ApexClass in 1.20 seconds
# Processed field Id in object ApexComponent
# Processed field NamespacePrefix in object ApexComponent
# Processed field Name in object ApexComponent
# Processed field ApiVersion in object ApexComponent
# Processed field MasterLabel in object ApexComponent
# Processed object ApexComponent in 0.43 seconds
# Processed field Id in object ApexEmailNotification
# Processed field IsDeleted in object ApexEmailNotification
# Processed field CreatedDate in object ApexEmailNotification
# Processed field CreatedById in object ApexEmailNotification
# Processed field LastModifiedDate in object ApexEmailNotification
# Processed object ApexEmailNotification in 0.33 seconds
# Processed field Id in object ApexLog
# Processed field LogUserId in object ApexLog
# Processed field LogLength in object ApexLog
# Processed field LastModifiedDate in object ApexLog
# Processed field Request in object ApexLog
# Processed object ApexLog in 0.65 seconds
# Processed field Id in object ApexPage
# Processed field NamespacePrefix in object ApexPage
# Processed field Name in object ApexPage
# Processed field ApiVersion in object ApexPage
# Processed field MasterLabel in object ApexPage
# Processed object ApexPage in 0.50 seconds
# Processed field Id in object ApexPageInfo
# Processed field DurableId in object ApexPageInfo
# Processed field ApexPageId in object ApexPageInfo
# Processed field Name in object ApexPageInfo
# Processed field NameSpacePrefix in object ApexPageInfo
# Processed object ApexPageInfo in 0.39 seconds
# Processed field Id in object ApexTestQueueItem
# Processed field CreatedDate in object ApexTestQueueItem
# Processed field CreatedById in object ApexTestQueueItem
# Processed field SystemModstamp in object ApexTestQueueItem
# Processed field ApexClassId in object ApexTestQueueItem
# Processed object ApexTestQueueItem in 0.31 seconds
# Processed field Id in object ApexTestResult
# Processed field SystemModstamp in object ApexTestResult
# Processed field TestTimestamp in object ApexTestResult
# Processed field Outcome in object ApexTestResult
# Processed field ApexClassId in object ApexTestResult
# Processed object ApexTestResult in 0.39 seconds
# Processed field Id in object ApexTestResultLimits
# Processed field IsDeleted in object ApexTestResultLimits
# Processed field CreatedDate in object ApexTestResultLimits
# Processed field CreatedById in object ApexTestResultLimits
# Processed field LastModifiedDate in object ApexTestResultLimits
# Processed object ApexTestResultLimits in 0.36 seconds
# Processed field Id in object ApexTestRunResult
# Processed field IsDeleted in object ApexTestRunResult
# Processed field CreatedDate in object ApexTestRunResult
# Processed field CreatedById in object ApexTestRunResult
# Processed field LastModifiedDate in object ApexTestRunResult
# Processed object ApexTestRunResult in 0.32 seconds
# Processed field Id in object ApexTestSuite
# Processed field IsDeleted in object ApexTestSuite
# Processed field CreatedDate in object ApexTestSuite
# Processed field CreatedById in object ApexTestSuite
# Processed field LastModifiedDate in object ApexTestSuite
# Processed object ApexTestSuite in 0.33 seconds
# Processed field Id in object ApexTrigger
# Processed field NamespacePrefix in object ApexTrigger
# Processed field Name in object ApexTrigger
# Processed field TableEnumOrId in object ApexTrigger
# Processed field UsageBeforeInsert in object ApexTrigger
# Processed object ApexTrigger in 0.62 seconds
# Skipping ApexTypeImplementor due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+ApexTypeImplementor. Response content: [{'message': 'ApexTypeImplementor: a filter on a reified column is required [InterfaceName,DurableId]', 'errorCode': 'MALFORMED_QUERY'}]
# Processed field Id in object AppAnalyticsQueryRequest
# Processed field IsDeleted in object AppAnalyticsQueryRequest
# Processed field Name in object AppAnalyticsQueryRequest
# Processed field CreatedDate in object AppAnalyticsQueryRequest
# Processed field CreatedById in object AppAnalyticsQueryRequest
# Processed object AppAnalyticsQueryRequest in 0.32 seconds
# Processed field Id in object AppDefinition
# Processed field DurableId in object AppDefinition
# Processed field Label in object AppDefinition
# Processed field MasterLabel in object AppDefinition
# Processed field NamespacePrefix in object AppDefinition
# Processed object AppDefinition in 0.33 seconds
# Processed field Id in object AppMenuItem
# Processed field IsDeleted in object AppMenuItem
# Processed field CreatedDate in object AppMenuItem
# Processed field CreatedById in object AppMenuItem
# Processed field LastModifiedDate in object AppMenuItem
# Processed object AppMenuItem in 1.48 seconds
# Skipping AppTabMember due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+AppTabMember. Response content: [{'message': 'AppTabMember: a filter on a reified column is required [AppDefinitionId,TabDefinitionId,DurableId]', 'errorCode': 'MALFORMED_QUERY'}]
# Processed field Id in object ApplicationSubtypeDefinition
# Processed field IsDeleted in object ApplicationSubtypeDefinition
# Processed field DeveloperName in object ApplicationSubtypeDefinition
# Processed field Language in object ApplicationSubtypeDefinition
# Processed field MasterLabel in object ApplicationSubtypeDefinition
# Processed object ApplicationSubtypeDefinition in 0.33 seconds
# Processed field Id in object Asset
# Processed field ContactId in object Asset
# Processed field AccountId in object Asset
# Processed field ParentId in object Asset
# Processed field RootAssetId in object Asset
# Processed object Asset in 0.35 seconds
# Skipping AssetChangeEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+AssetChangeEvent. Response content: [{'message': 'entity type AssetChangeEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object AssetFeed
# Processed field ParentId in object AssetFeed
# Processed field Type in object AssetFeed
# Processed field CreatedById in object AssetFeed
# Processed field CreatedDate in object AssetFeed
# Processed object AssetFeed in 0.35 seconds
# Processed field Id in object AssetHistory
# Processed field IsDeleted in object AssetHistory
# Processed field AssetId in object AssetHistory
# Processed field CreatedById in object AssetHistory
# Processed field CreatedDate in object AssetHistory
# Processed object AssetHistory in 0.36 seconds
# Processed field Id in object AssetRelationship
# Processed field IsDeleted in object AssetRelationship
# Processed field AssetRelationshipNumber in object AssetRelationship
# Processed field CurrencyIsoCode in object AssetRelationship
# Processed field CreatedDate in object AssetRelationship
# Processed object AssetRelationship in 0.30 seconds
# Processed field Id in object AssetRelationshipFeed
# Processed field ParentId in object AssetRelationshipFeed
# Processed field Type in object AssetRelationshipFeed
# Processed field CreatedById in object AssetRelationshipFeed
# Processed field CreatedDate in object AssetRelationshipFeed
# Processed object AssetRelationshipFeed in 0.33 seconds
# Processed field Id in object AssetRelationshipHistory
# Processed field IsDeleted in object AssetRelationshipHistory
# Processed field AssetRelationshipId in object AssetRelationshipHistory
# Processed field CreatedById in object AssetRelationshipHistory
# Processed field CreatedDate in object AssetRelationshipHistory
# Processed object AssetRelationshipHistory in 0.88 seconds
# Processed field Id in object AssetShare
# Processed field AssetId in object AssetShare
# Processed field UserOrGroupId in object AssetShare
# Processed field AssetAccessLevel in object AssetShare
# Processed field RowCause in object AssetShare
# Processed object AssetShare in 0.46 seconds
# Skipping AssetTokenEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+AssetTokenEvent. Response content: [{'message': 'entity type AssetTokenEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Skipping Asset_Contact__ChangeEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+Asset_Contact__ChangeEvent. Response content: [{'message': 'entity type Asset_Contact__ChangeEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object Asset_Contact__Share
# Processed field ParentId in object Asset_Contact__Share
# Processed field UserOrGroupId in object Asset_Contact__Share
# Processed field AccessLevel in object Asset_Contact__Share
# Processed field RowCause in object Asset_Contact__Share
# Processed object Asset_Contact__Share in 0.62 seconds
# Processed field Id in object Asset_Contact__c
# Processed field OwnerId in object Asset_Contact__c
# Processed field IsDeleted in object Asset_Contact__c
# Processed field Name in object Asset_Contact__c
# Processed field CurrencyIsoCode in object Asset_Contact__c
# Processed object Asset_Contact__c in 0.81 seconds
# Processed field Id in object AssignmentRule
# Processed field Name in object AssignmentRule
# Processed field SobjectType in object AssignmentRule
# Processed field Active in object AssignmentRule
# Processed field CreatedById in object AssignmentRule
# Processed object AssignmentRule in 0.33 seconds
# Processed field Id in object AssociatedLocation
# Processed field IsDeleted in object AssociatedLocation
# Processed field AssociatedLocationNumber in object AssociatedLocation
# Processed field CurrencyIsoCode in object AssociatedLocation
# Processed field CreatedDate in object AssociatedLocation
# Processed object AssociatedLocation in 0.31 seconds
# Processed field Id in object AssociatedLocationHistory
# Processed field IsDeleted in object AssociatedLocationHistory
# Processed field AssociatedLocationId in object AssociatedLocationHistory
# Processed field CreatedById in object AssociatedLocationHistory
# Processed field CreatedDate in object AssociatedLocationHistory
# Processed object AssociatedLocationHistory in 0.44 seconds
# Processed field Id in object AsyncApexJob
# Processed field CreatedDate in object AsyncApexJob
# Processed field CreatedById in object AsyncApexJob
# Processed field JobType in object AsyncApexJob
# Processed field ApexClassId in object AsyncApexJob
# Processed object AsyncApexJob in 2.55 seconds
# Skipping AsyncOperationEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+AsyncOperationEvent. Response content: [{'message': 'entity type AsyncOperationEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Skipping AsyncOperationStatus due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+AsyncOperationStatus. Response content: [{'message': 'entity type AsyncOperationStatus does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object AsyncOperationTracker
# Processed field OwnerId in object AsyncOperationTracker
# Processed field IsDeleted in object AsyncOperationTracker
# Processed field AsyncOperationNumber in object AsyncOperationTracker
# Processed field CreatedDate in object AsyncOperationTracker
# Processed object AsyncOperationTracker in 0.34 seconds
# Processed field Id in object AsyncOperationTrackerShare
# Processed field ParentId in object AsyncOperationTrackerShare
# Processed field UserOrGroupId in object AsyncOperationTrackerShare
# Processed field AccessLevel in object AsyncOperationTrackerShare
# Processed field RowCause in object AsyncOperationTrackerShare
# Processed object AsyncOperationTrackerShare in 0.32 seconds
# Skipping AttachedContentDocument due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+AttachedContentDocument. Response content: [{'message': 'entity type AttachedContentDocument does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Skipping AttachedContentNote due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+AttachedContentNote. Response content: [{'message': 'entity type AttachedContentNote does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object Attachment
# Processed field IsDeleted in object Attachment
# Processed field ParentId in object Attachment
# Processed field Name in object Attachment
# Processed field IsPrivate in object Attachment
# Processed object Attachment in 1.42 seconds
# Processed field Id in object AttributeCategory
# Processed field OwnerId in object AttributeCategory
# Processed field IsDeleted in object AttributeCategory
# Processed field Name in object AttributeCategory
# Processed field CurrencyIsoCode in object AttributeCategory
# Processed object AttributeCategory in 0.39 seconds
# Processed field Id in object AttributeCategoryAttribute
# Processed field OwnerId in object AttributeCategoryAttribute
# Processed field IsDeleted in object AttributeCategoryAttribute
# Processed field Name in object AttributeCategoryAttribute
# Processed field CurrencyIsoCode in object AttributeCategoryAttribute
# Processed object AttributeCategoryAttribute in 0.44 seconds
# Processed field Id in object AttributeCategoryAttributeFeed
# Processed field ParentId in object AttributeCategoryAttributeFeed
# Processed field Type in object AttributeCategoryAttributeFeed
# Processed field CreatedById in object AttributeCategoryAttributeFeed
# Processed field CreatedDate in object AttributeCategoryAttributeFeed
# Processed object AttributeCategoryAttributeFeed in 0.32 seconds
# Processed field Id in object AttributeCategoryAttributeHistory
# Processed field IsDeleted in object AttributeCategoryAttributeHistory
# Processed field AttributeCategoryAttributeId in object AttributeCategoryAttributeHistory
# Processed field CreatedById in object AttributeCategoryAttributeHistory
# Processed field CreatedDate in object AttributeCategoryAttributeHistory
# Processed object AttributeCategoryAttributeHistory in 0.36 seconds
# Processed field Id in object AttributeCategoryAttributeShare
# Processed field ParentId in object AttributeCategoryAttributeShare
# Processed field UserOrGroupId in object AttributeCategoryAttributeShare
# Processed field AccessLevel in object AttributeCategoryAttributeShare
# Processed field RowCause in object AttributeCategoryAttributeShare
# Processed object AttributeCategoryAttributeShare in 0.38 seconds
# Processed field Id in object AttributeCategoryFeed
# Processed field ParentId in object AttributeCategoryFeed
# Processed field Type in object AttributeCategoryFeed
# Processed field CreatedById in object AttributeCategoryFeed
# Processed field CreatedDate in object AttributeCategoryFeed
# Processed object AttributeCategoryFeed in 0.29 seconds
# Processed field Id in object AttributeCategoryHistory
# Processed field IsDeleted in object AttributeCategoryHistory
# Processed field AttributeCategoryId in object AttributeCategoryHistory
# Processed field CreatedById in object AttributeCategoryHistory
# Processed field CreatedDate in object AttributeCategoryHistory
# Processed object AttributeCategoryHistory in 0.46 seconds
# Processed field Id in object AttributeCategoryShare
# Processed field ParentId in object AttributeCategoryShare
# Processed field UserOrGroupId in object AttributeCategoryShare
# Processed field AccessLevel in object AttributeCategoryShare
# Processed field RowCause in object AttributeCategoryShare
# Processed object AttributeCategoryShare in 0.38 seconds
# Processed field Id in object AttributeDefinition
# Processed field OwnerId in object AttributeDefinition
# Processed field IsDeleted in object AttributeDefinition
# Processed field Name in object AttributeDefinition
# Processed field CurrencyIsoCode in object AttributeDefinition
# Processed object AttributeDefinition in 0.35 seconds
# Processed field Id in object AttributeDefinitionFeed
# Processed field ParentId in object AttributeDefinitionFeed
# Processed field Type in object AttributeDefinitionFeed
# Processed field CreatedById in object AttributeDefinitionFeed
# Processed field CreatedDate in object AttributeDefinitionFeed
# Processed object AttributeDefinitionFeed in 0.35 seconds
# Processed field Id in object AttributeDefinitionHistory
# Processed field IsDeleted in object AttributeDefinitionHistory
# Processed field AttributeDefinitionId in object AttributeDefinitionHistory
# Processed field CreatedById in object AttributeDefinitionHistory
# Processed field CreatedDate in object AttributeDefinitionHistory
# Processed object AttributeDefinitionHistory in 0.39 seconds
# Processed field Id in object AttributeDefinitionShare
# Processed field ParentId in object AttributeDefinitionShare
# Processed field UserOrGroupId in object AttributeDefinitionShare
# Processed field AccessLevel in object AttributeDefinitionShare
# Processed field RowCause in object AttributeDefinitionShare
# Processed object AttributeDefinitionShare in 0.29 seconds
# Processed field Id in object AttributePicklist
# Processed field OwnerId in object AttributePicklist
# Processed field IsDeleted in object AttributePicklist
# Processed field Name in object AttributePicklist
# Processed field CurrencyIsoCode in object AttributePicklist
# Processed object AttributePicklist in 0.34 seconds
# Processed field Id in object AttributePicklistFeed
# Processed field ParentId in object AttributePicklistFeed
# Processed field Type in object AttributePicklistFeed
# Processed field CreatedById in object AttributePicklistFeed
# Processed field CreatedDate in object AttributePicklistFeed
# Processed object AttributePicklistFeed in 0.30 seconds
# Processed field Id in object AttributePicklistHistory
# Processed field IsDeleted in object AttributePicklistHistory
# Processed field AttributePicklistId in object AttributePicklistHistory
# Processed field CreatedById in object AttributePicklistHistory
# Processed field CreatedDate in object AttributePicklistHistory
# Processed object AttributePicklistHistory in 0.37 seconds
# Processed field Id in object AttributePicklistShare
# Processed field ParentId in object AttributePicklistShare
# Processed field UserOrGroupId in object AttributePicklistShare
# Processed field AccessLevel in object AttributePicklistShare
# Processed field RowCause in object AttributePicklistShare
# Processed object AttributePicklistShare in 0.30 seconds
# Processed field Id in object AttributePicklistValue
# Processed field IsDeleted in object AttributePicklistValue
# Processed field Name in object AttributePicklistValue
# Processed field CurrencyIsoCode in object AttributePicklistValue
# Processed field CreatedDate in object AttributePicklistValue
# Processed object AttributePicklistValue in 0.46 seconds
# Processed field Id in object AttributePicklistValueFeed
# Processed field ParentId in object AttributePicklistValueFeed
# Processed field Type in object AttributePicklistValueFeed
# Processed field CreatedById in object AttributePicklistValueFeed
# Processed field CreatedDate in object AttributePicklistValueFeed
# Processed object AttributePicklistValueFeed in 0.32 seconds
# Processed field Id in object AttributePicklistValueHistory
# Processed field IsDeleted in object AttributePicklistValueHistory
# Processed field AttributePicklistValueId in object AttributePicklistValueHistory
# Processed field CreatedById in object AttributePicklistValueHistory
# Processed field CreatedDate in object AttributePicklistValueHistory
# Processed object AttributePicklistValueHistory in 0.36 seconds
# Processed field Id in object Audience
# Processed field IsDeleted in object Audience
# Processed field DeveloperName in object Audience
# Processed field Language in object Audience
# Processed field MasterLabel in object Audience
# Processed object Audience in 0.33 seconds
# Processed field Id in object AuditTrailFileExport
# Processed field OwnerId in object AuditTrailFileExport
# Processed field IsDeleted in object AuditTrailFileExport
# Processed field Name in object AuditTrailFileExport
# Processed field CurrencyIsoCode in object AuditTrailFileExport
# Processed object AuditTrailFileExport in 0.39 seconds
# Processed field Id in object AuditTrailFileExportShare
# Processed field ParentId in object AuditTrailFileExportShare
# Processed field UserOrGroupId in object AuditTrailFileExportShare
# Processed field AccessLevel in object AuditTrailFileExportShare
# Processed field RowCause in object AuditTrailFileExportShare
# Processed object AuditTrailFileExportShare in 0.38 seconds
# Skipping Audit_History__ChangeEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+Audit_History__ChangeEvent. Response content: [{'message': 'entity type Audit_History__ChangeEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object Audit_History__c
# Processed field IsDeleted in object Audit_History__c
# Processed field Name in object Audit_History__c
# Processed field CurrencyIsoCode in object Audit_History__c
# Processed field CreatedDate in object Audit_History__c
# Processed object Audit_History__c in 0.78 seconds
# Skipping Audit_Type_Categories__ChangeEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+Audit_Type_Categories__ChangeEvent. Response content: [{'message': 'entity type Audit_Type_Categories__ChangeEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object Audit_Type_Categories__Share
# Processed field ParentId in object Audit_Type_Categories__Share
# Processed field UserOrGroupId in object Audit_Type_Categories__Share
# Processed field AccessLevel in object Audit_Type_Categories__Share
# Processed field RowCause in object Audit_Type_Categories__Share
# Processed object Audit_Type_Categories__Share in 0.41 seconds
# Processed field Id in object Audit_Type_Categories__c
# Processed field OwnerId in object Audit_Type_Categories__c
# Processed field IsDeleted in object Audit_Type_Categories__c
# Processed field Name in object Audit_Type_Categories__c
# Processed field CurrencyIsoCode in object Audit_Type_Categories__c
# Processed object Audit_Type_Categories__c in 0.35 seconds
# ...
# Processed field Id in object relmatrix__Involved_User__c
# Processed field OwnerId in object relmatrix__Involved_User__c
# Processed field IsDeleted in object relmatrix__Involved_User__c
# Processed field Name in object relmatrix__Involved_User__c
# Processed field CurrencyIsoCode in object relmatrix__Involved_User__c
# Processed object relmatrix__Involved_User__c in 0.36 seconds
# Skipping report_sender__Custom_Template__ChangeEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+report_sender__Custom_Template__ChangeEvent. Response content: [{'message': 'entity type report_sender__Custom_Template__ChangeEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object report_sender__Custom_Template__Share
# Processed field ParentId in object report_sender__Custom_Template__Share
# Processed field UserOrGroupId in object report_sender__Custom_Template__Share
# Processed field AccessLevel in object report_sender__Custom_Template__Share
# Processed field RowCause in object report_sender__Custom_Template__Share
# Processed object report_sender__Custom_Template__Share in 0.34 seconds
# Processed field Id in object report_sender__Custom_Template__c
# Processed field OwnerId in object report_sender__Custom_Template__c
# Processed field IsDeleted in object report_sender__Custom_Template__c
# Processed field Name in object report_sender__Custom_Template__c
# Processed field CurrencyIsoCode in object report_sender__Custom_Template__c
# Processed object report_sender__Custom_Template__c in 0.40 seconds
# Skipping report_sender__DashboardView__ChangeEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+report_sender__DashboardView__ChangeEvent. Response content: [{'message': 'entity type report_sender__DashboardView__ChangeEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object report_sender__DashboardView__Share
# Processed field ParentId in object report_sender__DashboardView__Share
# Processed field UserOrGroupId in object report_sender__DashboardView__Share
# Processed field AccessLevel in object report_sender__DashboardView__Share
# Processed field RowCause in object report_sender__DashboardView__Share
# Processed object report_sender__DashboardView__Share in 0.31 seconds
# Processed field Id in object report_sender__DashboardView__c
# Processed field OwnerId in object report_sender__DashboardView__c
# Processed field IsDeleted in object report_sender__DashboardView__c
# Processed field Name in object report_sender__DashboardView__c
# Processed field CurrencyIsoCode in object report_sender__DashboardView__c
# Processed object report_sender__DashboardView__c in 0.44 seconds
# Skipping report_sender__Email_Data__ChangeEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+report_sender__Email_Data__ChangeEvent. Response content: [{'message': 'entity type report_sender__Email_Data__ChangeEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object report_sender__Email_Data__Share
# Processed field ParentId in object report_sender__Email_Data__Share
# Processed field UserOrGroupId in object report_sender__Email_Data__Share
# Processed field AccessLevel in object report_sender__Email_Data__Share
# Processed field RowCause in object report_sender__Email_Data__Share
# Processed object report_sender__Email_Data__Share in 0.36 seconds
# Processed field Id in object report_sender__Email_Data__c
# Processed field OwnerId in object report_sender__Email_Data__c
# Processed field IsDeleted in object report_sender__Email_Data__c
# Processed field Name in object report_sender__Email_Data__c
# Processed field CurrencyIsoCode in object report_sender__Email_Data__c
# Processed object report_sender__Email_Data__c in 0.34 seconds
# Skipping report_sender__Email_Jobs__ChangeEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+report_sender__Email_Jobs__ChangeEvent. Response content: [{'message': 'entity type report_sender__Email_Jobs__ChangeEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object report_sender__Email_Jobs__Share
# Processed field ParentId in object report_sender__Email_Jobs__Share
# Processed field UserOrGroupId in object report_sender__Email_Jobs__Share
# Processed field AccessLevel in object report_sender__Email_Jobs__Share
# Processed field RowCause in object report_sender__Email_Jobs__Share
# Processed object report_sender__Email_Jobs__Share in 0.33 seconds
# Processed field Id in object report_sender__Email_Jobs__c
# Processed field OwnerId in object report_sender__Email_Jobs__c
# Processed field IsDeleted in object report_sender__Email_Jobs__c
# Processed field Name in object report_sender__Email_Jobs__c
# Processed field CurrencyIsoCode in object report_sender__Email_Jobs__c
# Processed object report_sender__Email_Jobs__c in 0.31 seconds
# Skipping report_sender__Post_Update_Custom_Settings__ChangeEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+report_sender__Post_Update_Custom_Settings__ChangeEvent. Response content: [{'message': 'entity type report_sender__Post_Update_Custom_Settings__ChangeEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object report_sender__Post_Update_Custom_Settings__c
# Processed field IsDeleted in object report_sender__Post_Update_Custom_Settings__c
# Processed field Name in object report_sender__Post_Update_Custom_Settings__c
# Processed field CurrencyIsoCode in object report_sender__Post_Update_Custom_Settings__c
# Processed field SetupOwnerId in object report_sender__Post_Update_Custom_Settings__c
# Processed object report_sender__Post_Update_Custom_Settings__c in 0.37 seconds
# Processed field Id in object report_sender__Report_Sender_Columns_Setting__mdt
# Processed field DeveloperName in object report_sender__Report_Sender_Columns_Setting__mdt
# Processed field MasterLabel in object report_sender__Report_Sender_Columns_Setting__mdt
# Processed field Language in object report_sender__Report_Sender_Columns_Setting__mdt
# Processed field NamespacePrefix in object report_sender__Report_Sender_Columns_Setting__mdt
# Processed object report_sender__Report_Sender_Columns_Setting__mdt in 0.29 seconds
# Skipping report_sender__Schedule_Log__ChangeEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+report_sender__Schedule_Log__ChangeEvent. Response content: [{'message': 'entity type report_sender__Schedule_Log__ChangeEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object report_sender__Schedule_Log__Share
# Processed field ParentId in object report_sender__Schedule_Log__Share
# Processed field UserOrGroupId in object report_sender__Schedule_Log__Share
# Processed field AccessLevel in object report_sender__Schedule_Log__Share
# Processed field RowCause in object report_sender__Schedule_Log__Share
# Processed object report_sender__Schedule_Log__Share in 0.81 seconds
# Processed field Id in object report_sender__Schedule_Log__c
# Processed field OwnerId in object report_sender__Schedule_Log__c
# Processed field IsDeleted in object report_sender__Schedule_Log__c
# Processed field Name in object report_sender__Schedule_Log__c
# Processed field CurrencyIsoCode in object report_sender__Schedule_Log__c
# Processed object report_sender__Schedule_Log__c in 0.53 seconds
# Skipping smartlists__Context__ChangeEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+smartlists__Context__ChangeEvent. Response content: [{'message': 'entity type smartlists__Context__ChangeEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object smartlists__Context__Share
# Processed field ParentId in object smartlists__Context__Share
# Processed field UserOrGroupId in object smartlists__Context__Share
# Processed field AccessLevel in object smartlists__Context__Share
# Processed field RowCause in object smartlists__Context__Share
# Processed object smartlists__Context__Share in 0.39 seconds
# Processed field Id in object smartlists__Context__c
# Processed field OwnerId in object smartlists__Context__c
# Processed field IsDeleted in object smartlists__Context__c
# Processed field Name in object smartlists__Context__c
# Processed field CurrencyIsoCode in object smartlists__Context__c
# Processed object smartlists__Context__c in 0.59 seconds
# Processed field Id in object smartlists__Smart_List_Action__mdt
# Processed field DeveloperName in object smartlists__Smart_List_Action__mdt
# Processed field MasterLabel in object smartlists__Smart_List_Action__mdt
# Processed field Language in object smartlists__Smart_List_Action__mdt
# Processed field NamespacePrefix in object smartlists__Smart_List_Action__mdt
# Processed object smartlists__Smart_List_Action__mdt in 0.33 seconds
# Processed field Id in object smartlists__Smart_List_Definition__mdt
# Processed field DeveloperName in object smartlists__Smart_List_Definition__mdt
# Processed field MasterLabel in object smartlists__Smart_List_Definition__mdt
# Processed field Language in object smartlists__Smart_List_Definition__mdt
# Processed field NamespacePrefix in object smartlists__Smart_List_Definition__mdt
# Processed object smartlists__Smart_List_Definition__mdt in 0.41 seconds
# Processed field Id in object smartlists__Smart_List_Field__mdt
# Processed field DeveloperName in object smartlists__Smart_List_Field__mdt
# Processed field MasterLabel in object smartlists__Smart_List_Field__mdt
# Processed field Language in object smartlists__Smart_List_Field__mdt
# Processed field NamespacePrefix in object smartlists__Smart_List_Field__mdt
# Processed object smartlists__Smart_List_Field__mdt in 0.35 seconds
# Processed field Id in object smartlists__Smart_List_Filter__mdt
# Processed field DeveloperName in object smartlists__Smart_List_Filter__mdt
# Processed field MasterLabel in object smartlists__Smart_List_Filter__mdt
# Processed field Language in object smartlists__Smart_List_Filter__mdt
# Processed field NamespacePrefix in object smartlists__Smart_List_Filter__mdt
# Processed object smartlists__Smart_List_Filter__mdt in 0.28 seconds
# Processed field Id in object spdf__Content_Formatting__mdt
# Processed field DeveloperName in object spdf__Content_Formatting__mdt
# Processed field MasterLabel in object spdf__Content_Formatting__mdt
# Processed field Language in object spdf__Content_Formatting__mdt
# Processed field NamespacePrefix in object spdf__Content_Formatting__mdt
# Processed object spdf__Content_Formatting__mdt in 0.29 seconds
# Skipping spdf__Simple_PDF__ChangeEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+spdf__Simple_PDF__ChangeEvent. Response content: [{'message': 'entity type spdf__Simple_PDF__ChangeEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object spdf__Simple_PDF__Share
# Processed field ParentId in object spdf__Simple_PDF__Share
# Processed field UserOrGroupId in object spdf__Simple_PDF__Share
# Processed field AccessLevel in object spdf__Simple_PDF__Share
# Processed field RowCause in object spdf__Simple_PDF__Share
# Processed object spdf__Simple_PDF__Share in 0.38 seconds
# Processed field Id in object spdf__Simple_PDF__c
# Processed field OwnerId in object spdf__Simple_PDF__c
# Processed field IsDeleted in object spdf__Simple_PDF__c
# Processed field Name in object spdf__Simple_PDF__c
# Processed field CurrencyIsoCode in object spdf__Simple_PDF__c
# Processed object spdf__Simple_PDF__c in 0.34 seconds
# Skipping ssot__AccountContact__dlm due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+ssot__AccountContact__dlm. Response content: [{'message': 'SELECT COUNT() is not supported by ssot__AccountContact__dlm.', 'errorCode': 'UNSUPPORTED_QUERY'}]
# Skipping ssot__Account__dlm due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+ssot__Account__dlm. Response content: [{'message': 'SELECT COUNT() is not supported by ssot__Account__dlm.', 'errorCode': 'UNSUPPORTED_QUERY'}]
# Skipping ssot__ContactPointAddress__dlm due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+ssot__ContactPointAddress__dlm. Response content: [{'message': 'SELECT COUNT() is not supported by ssot__ContactPointAddress__dlm.', 'errorCode': 'UNSUPPORTED_QUERY'}]
# Skipping ssot__ContactPointEmail__dlm due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+ssot__ContactPointEmail__dlm. Response content: [{'message': 'SELECT COUNT() is not supported by ssot__ContactPointEmail__dlm.', 'errorCode': 'UNSUPPORTED_QUERY'}]
# Skipping ssot__ContactPointPhone__dlm due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+ssot__ContactPointPhone__dlm. Response content: [{'message': 'SELECT COUNT() is not supported by ssot__ContactPointPhone__dlm.', 'errorCode': 'UNSUPPORTED_QUERY'}]
# Skipping ssot__Individual__dlm due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+ssot__Individual__dlm. Response content: [{'message': 'SELECT COUNT() is not supported by ssot__Individual__dlm.', 'errorCode': 'UNSUPPORTED_QUERY'}]
# Skipping timeline__Timeline_Child_Object__ChangeEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+timeline__Timeline_Child_Object__ChangeEvent. Response content: [{'message': 'entity type timeline__Timeline_Child_Object__ChangeEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object timeline__Timeline_Child_Object__c
# Processed field IsDeleted in object timeline__Timeline_Child_Object__c
# Processed field Name in object timeline__Timeline_Child_Object__c
# Processed field CurrencyIsoCode in object timeline__Timeline_Child_Object__c
# Processed field CreatedDate in object timeline__Timeline_Child_Object__c
# Processed object timeline__Timeline_Child_Object__c in 0.36 seconds
# Skipping timeline__Timeline_Configuration__ChangeEvent due to error: Malformed request https://my-edwardmellor.my.salesforce.com/services/data/v59.0/query/?q=SELECT+COUNT%28%29+FROM+timeline__Timeline_Configuration__ChangeEvent. Response content: [{'message': 'entity type timeline__Timeline_Configuration__ChangeEvent does not support query', 'errorCode': 'INVALID_TYPE_FOR_OPERATION'}]
# Processed field Id in object timeline__Timeline_Configuration__c
# Processed field OwnerId in object timeline__Timeline_Configuration__c
# Processed field IsDeleted in object timeline__Timeline_Configuration__c
# Processed field Name in object timeline__Timeline_Configuration__c
# Processed field CurrencyIsoCode in object timeline__Timeline_Configuration__c
# Processed object timeline__Timeline_Configuration__c in 0.36 seconds
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 49
#      46 # Assuming you have already connected to Salesforce and retrieved metadata_df
#      47 completeness_df = calculate_data_completeness(sf, metadata_df, max_fields_per_object=5)
# ---> 49 import ace_tools as tools
#      50 tools.display_dataframe_to_user(name="Data Completeness", dataframe=completeness_df)
#
# ModuleNotFoundError: No module named 'ace_tools'

# %%
completeness_df.to_excel('completeness_df.xlsx')

# %% [markdown]
# ## Analyze Relationships

# %%
def analyze_relationships(metadata_df):
    relationships = metadata_df.dropna(subset=["relationship"]).copy()
    relationships["connection"] = relationships.apply(lambda row: f"{row['object']} -> {row['related_to']}", axis=1)
    return relationships[["object", "field", "type", "relationship", "related_to", "connection"]]

relationships_df = analyze_relationships(metadata_df)
relationships_df
# Out:
#                                     object  \
# 45                 ACTIVITES_EMv2__History
# 46                 ACTIVITES_EMv2__History
# 57                       ACTIVITES_EMv2__c
# 59                       ACTIVITES_EMv2__c
# 61                       ACTIVITES_EMv2__c
# ...                                    ...
# 44380   timeline__Timeline_Child_Object__c
# 44382   timeline__Timeline_Child_Object__c
# 44418  timeline__Timeline_Configuration__c
# 44423  timeline__Timeline_Configuration__c
# 44425  timeline__Timeline_Configuration__c
#
#                                      field       type  \
# 45                                ParentId  reference
# 46                             CreatedById  reference
# 57                             CreatedById  reference
# 59                        LastModifiedById  reference
# 61                        ACTIVITY_Type__c  reference
# ...                                    ...        ...
# 44380                     LastModifiedById  reference
# 44382  timeline__Timeline_Configuration__c  reference
# 44418                              OwnerId  reference
# 44423                          CreatedById  reference
# 44425                     LastModifiedById  reference
#
#                               relationship  \
# 45                                  Parent
# 46                               CreatedBy
# 57                               CreatedBy
# 59                          LastModifiedBy
# 61                        ACTIVITY_Type__r
# ...                                    ...
# 44380                       LastModifiedBy
# 44382  timeline__Timeline_Configuration__r
# 44418                                Owner
# 44423                            CreatedBy
# 44425                       LastModifiedBy
#
#                                   related_to  \
# 45                       [ACTIVITES_EMv2__c]
# 46                                    [User]
# 57                                    [User]
# 59                                    [User]
# 61               [ACTIVITY_Template_EMv2__c]
# ...                                      ...
# 44380                                 [User]
# 44382  [timeline__Timeline_Configuration__c]
# 44418                          [Group, User]
# 44423                                 [User]
# 44425                                 [User]
#
#                                               connection
# 45      ACTIVITES_EMv2__History -> ['ACTIVITES_EMv2__c']
# 46                   ACTIVITES_EMv2__History -> ['User']
# 57                         ACTIVITES_EMv2__c -> ['User']
# 59                         ACTIVITES_EMv2__c -> ['User']
# 61     ACTIVITES_EMv2__c -> ['ACTIVITY_Template_EMv2_...
# ...                                                  ...
# 44380     timeline__Timeline_Child_Object__c -> ['User']
# 44382  timeline__Timeline_Child_Object__c -> ['timeli...
# 44418  timeline__Timeline_Configuration__c -> ['Group...
# 44423    timeline__Timeline_Configuration__c -> ['User']
# 44425    timeline__Timeline_Configuration__c -> ['User']
#
# [6315 rows x 6 columns]

# %%
relationships_df.to_excel('relationships_df.xlsx')

# %% [markdown]
# ## Query Producer from report

# %%
from simple_salesforce import Salesforce
import json
import os

def get_report_soql(sf, report_id):
    # Describe the report to get its details
    report_describe = sf.restful(f'analytics/reports/{report_id}/describe')
    
    # Extract the report metadata
    report_metadata = report_describe['reportMetadata']
    
    # Build the SOQL query
    select_clause = ', '.join(report_metadata['detailColumns'])
    from_clause = report_metadata['reportType']['type']
    
    # Handle the reportFilters more robustly
    where_clauses = []
    for filter_item in report_metadata['reportFilters']:
        if isinstance(filter_item, dict):
            column = filter_item.get('column')
            operator = filter_item.get('operator')
            value = filter_item.get('value')
            if column and operator:
                where_clause = f"{column} {operator} '{value}'" if value else f"{column} {operator}"
                where_clauses.append(where_clause)
    
    where_clause = ' AND '.join(where_clauses)
    
    soql = f"SELECT {select_clause} FROM {from_clause}"
    if where_clause:
        soql += f" WHERE {where_clause}"
    
    return soql

# Salesforce login credentials
sf_username = os.environ.get('SF_USERNAME')
sf_password = os.environ.get('SF_PASSWORD')
sf_security_token = os.environ.get('SF_SECURITY_TOKEN')

# Initialize Salesforce connection
sf = Salesforce(username=username, password=password, security_token=security_token)

# Specify the report ID
report_id = '00O8W0000071qebUAA'  # Your actual report ID

# Get the SOQL for the report
soql = get_report_soql(sf, report_id)

print(f"SOQL for report {report_id}:")
print(soql)
# Out:
# SOQL for report 00O8W0000071qebUAA:
# SELECT CUST_NAME, FK_NAME, CUST_CREATED_DATE, pba__Closing__c.pba__Listing__c, pba__Closing__c.Closing_Status__c, FK_pba__Offer__c.pba__Status__c, pba__Closing__c.Calculated_Fee__c, FK_pba__Offer__c.Source_Of_Funding__c FROM CustomEntity$pba__Closing__c@pba__Closing__c.pba__Offer__c WHERE CUST_RECORDTYPE equals 'Sale' AND pba__Closing__c.Office__c notEqual 'Auction'

# %% [markdown]
# ## Query Producer from report (task & Event)

# %%
from simple_salesforce import Salesforce
import json
import os

def get_report_soql(sf, report_id):
    # Describe the report to get its details
    report_describe = sf.restful(f'analytics/reports/{report_id}/describe')
    
    # Extract the report metadata
    report_metadata = report_describe['reportMetadata']
    
    # Build the SOQL query
    select_clause = ', '.join(report_metadata['detailColumns'])
    from_clause = report_metadata['reportType']['type']
    
    # Handle the reportFilters more robustly
    where_clauses = []
    for filter_item in report_metadata['reportFilters']:
        if isinstance(filter_item, dict):
            column = filter_item.get('column')
            operator = filter_item.get('operator')
            value = filter_item.get('value')
            if column and operator:
                where_clause = f"{column} {operator} '{value}'" if value else f"{column} {operator}"
                where_clauses.append(where_clause)
    
    where_clause = ' AND '.join(where_clauses)
    
    # Check if the report is on activities (Events and Tasks)
    if 'Activity' in from_clause:
        # Create separate queries for Events and Tasks
        event_soql = f"SELECT {select_clause} FROM Event"
        task_soql = f"SELECT {select_clause} FROM Task"
        
        if where_clause:
            event_soql += f" WHERE {where_clause}"
            task_soql += f" WHERE {where_clause}"
        
        # Combine the queries with UNION
        soql = f"({event_soql}) UNION ({task_soql})"
    else:
        # For non-activity reports, use the original logic
        soql = f"SELECT {select_clause} FROM {from_clause}"
        if where_clause:
            soql += f" WHERE {where_clause}"
    
    return soql

# Salesforce login credentials
sf_username = os.environ.get('SF_USERNAME')
sf_password = os.environ.get('SF_PASSWORD')
sf_security_token = os.environ.get('SF_SECURITY_TOKEN')

# Initialize Salesforce connection
sf = Salesforce(username=username, password=password, security_token=security_token)

# Specify the report ID
report_id = '00O8W0000071qebUAA'  # Your actual report ID

# Get the SOQL for the report
soql = get_report_soql(sf, report_id)

print(f"SOQL for report {report_id}:")
print(soql)
# Out:
# SOQL for report 00O8W0000071qebUAA:
# SELECT CUST_NAME, FK_NAME, CUST_CREATED_DATE, pba__Closing__c.pba__Listing__c, pba__Closing__c.Closing_Status__c, FK_pba__Offer__c.pba__Status__c, pba__Closing__c.Calculated_Fee__c, FK_pba__Offer__c.Source_Of_Funding__c FROM CustomEntity$pba__Closing__c@pba__Closing__c.pba__Offer__c WHERE CUST_RECORDTYPE equals 'Sale' AND pba__Closing__c.Office__c notEqual 'Auction'

# %% [markdown]
# ## Object & Columns & population

# %%
import requests
import pandas as pd
from simple_salesforce import Salesforce
import keyring
from concurrent.futures import ThreadPoolExecutor, as_completed

def connect_to_salesforce():
    username = keyring.get_password("salesforce", "username")
    password = keyring.get_password("salesforce", "password")
    security_token = keyring.get_password("salesforce", "security_token")
    consumer_key = keyring.get_password("salesforce", "consumer_key")
    consumer_secret = keyring.get_password("salesforce", "consumer_secret")

    token_url = "https://login.salesforce.com/services/oauth2/token"
    payload = {
        'grant_type': 'password',
        'client_id': consumer_key,
        'client_secret': consumer_secret,
        'username': username,
        'password': password + security_token
    }
    response = requests.post(token_url, data=payload)
    response.raise_for_status()

    access_token = response.json().get('access_token')
    instance_url = response.json().get('instance_url')

    return Salesforce(instance_url=instance_url, session_id=access_token)

def analyze_object(sf, obj_name):
    try:
        describe = getattr(sf, obj_name).describe()
        fields = describe['fields']
        
        results = []
        for field in fields:
            field_name = field['name']
            total_records = sf.query(f"SELECT COUNT() FROM {obj_name}")['totalSize']
            missing_records = sf.query(f"SELECT COUNT() FROM {obj_name} WHERE {field_name} = NULL")['totalSize']
            
            results.append({
                'object': obj_name,
                'field': field_name,
                'total_records': total_records,
                'missing_records': missing_records
            })
        
        return results
    except Exception as e:
        return [{
            'object': obj_name,
            'field': 'ERROR',
            'total_records': 0,
            'missing_records': 0,
            'error': str(e)
        }]

def analyze_salesforce_objects():
    sf = connect_to_salesforce()
    
    describe_result = sf.describe()
    all_objects = [obj['name'] for obj in describe_result['sobjects']]
    
    results = []
    with ThreadPoolExecutor(max_workers=10) as executor:
        future_to_obj = {executor.submit(analyze_object, sf, obj): obj for obj in all_objects}
        for future in as_completed(future_to_obj):
            results.extend(future.result())
    
    df = pd.DataFrame(results)
    df['missing_percentage'] = (df['missing_records'] / df['total_records']) * 100
    df = df.sort_values(['object', 'missing_percentage'], ascending=[True, False])
    
    df.to_csv('salesforce_detailed_object_analysis.csv', index=False)
    print("Analysis complete. Results saved to 'salesforce_detailed_object_analysis.csv'")

if __name__ == "__main__":
    analyze_salesforce_objects()
# Out:
# Analysis complete. Results saved to 'salesforce_detailed_object_analysis.csv'

# %% [markdown]
# ## How to connect two tables

# %%
import requests
from simple_salesforce import Salesforce
import keyring

def get_salesforce_session():
    # Retrieve your credentials
    username = keyring.get_password("salesforce", "username")
    password = keyring.get_password("salesforce", "password")
    security_token = keyring.get_password("salesforce", "security_token")
    consumer_key = keyring.get_password("salesforce", "consumer_key")
    consumer_secret = keyring.get_password("salesforce", "consumer_secret")

    # Obtain OAuth 2.0 token
    token_url = "https://login.salesforce.com/services/oauth2/token"
    payload = {
        'grant_type': 'password',
        'client_id': consumer_key,
        'client_secret': consumer_secret,
        'username': username,
        'password': password + security_token
    }
    response = requests.post(token_url, data=payload)
    response.raise_for_status()  # Check if the request was successful

    # Extract access token from the response
    access_token = response.json().get('access_token')
    instance_url = response.json().get('instance_url')

    # Authenticate to Salesforce using the access token
    sf = Salesforce(instance_url=instance_url, session_id=access_token)
    return sf

def get_object_fields(sf, object_name):
    object_metadata = sf.__getattr__(object_name).describe()
    fields = {field['name']: field for field in object_metadata['fields']}
    return fields

def find_common_fields(object1_fields, object2_fields):
    common_fields = set(object1_fields.keys()).intersection(set(object2_fields.keys()))
    return common_fields

def find_reference_fields(object_fields, reference_to_object):
    reference_fields = [field['name'] for field in object_fields.values()
                        if 'referenceTo' in field and reference_to_object in field['referenceTo']]
    return reference_fields

def get_joinable_fields(object1, object2):
    sf = get_salesforce_session()

    # Get fields for both objects
    object1_fields = get_object_fields(sf, object1)
    object2_fields = get_object_fields(sf, object2)

    # Find common fields by name
    common_fields = find_common_fields(object1_fields, object2_fields)

    # Find reference fields
    object1_references_to_object2 = find_reference_fields(object1_fields, object2)
    object2_references_to_object1 = find_reference_fields(object2_fields, object1)

    return {
        'common_fields': list(common_fields),
        'object1_references_to_object2': object1_references_to_object2,
        'object2_references_to_object1': object2_references_to_object1
    }

# Example usage
object1 = 'pba__Closing__c'
object2 = 'pba__Listing__c'
joinable_fields = get_joinable_fields(object1, object2)
print(f"Common Fields: {joinable_fields['common_fields']}")
print(f"{object1} references {object2} on fields: {joinable_fields['object1_references_to_object2']}")
print(f"{object2} references {object1} on fields: {joinable_fields['object2_references_to_object1']}")
# Out:
# Common Fields: ['LastModifiedDate', 'Joint_Agency_Calculated_Fee__c', 'Organisation_Domain__c', 'MB_logo__c', 'Current_User_Email__c', 'EPC__c', 'OwnerId', 'LastModifiedById', 'Rewards_Lister__c', 'Calculated_Fee__c', 'Name', 'Current_User_Name__c', 'IsDeleted', 'Vendor_Manager__c', 'Lister_Name_Formula__c', 'Pod_Match_Formula__c', 'MB_Property_Ombudsman_logo__c', 'LastViewedDate', 'RecordTypeId', 'Property_Owner_Household__c', 'Record_Type_Name__c', 'Current_User_Phone__c', 'LastActivityDate', 'Office__c', 'Exchange_Fee__c', 'CreatedById', 'CreatedDate', 'SystemModstamp', 'Pod__c', 'Lister_Name__c', 'CurrencyIsoCode', 'EM_logo__c', 'LastReferencedDate', 'Todays_date__c', 'EM_Openworks_Property_Ombudsman_logo__c', 'Entry_Fee__c', 'Solicitor_Referred_By_Who__c', 'Id', 'Success_Fee_To_Be_Paid__c']
# pba__Closing__c references pba__Listing__c on fields: ['pba__Listing__c']
# pba__Listing__c references pba__Closing__c on fields: []

# %%
import requests
import pandas as pd
from simple_salesforce import Salesforce
import keyring

def get_salesforce_session():
    # Retrieve your credentials
    username = keyring.get_password("salesforce", "username")
    password = keyring.get_password("salesforce", "password")
    security_token = keyring.get_password("salesforce", "security_token")
    consumer_key = keyring.get_password("salesforce", "consumer_key")
    consumer_secret = keyring.get_password("salesforce", "consumer_secret")

    # Obtain OAuth 2.0 token
    token_url = "https://login.salesforce.com/services/oauth2/token"
    payload = {
        'grant_type': 'password',
        'client_id': consumer_key,
        'client_secret': consumer_secret,
        'username': username,
        'password': password + security_token
    }
    response = requests.post(token_url, data=payload)
    response.raise_for_status()  # Check if the request was successful

    # Extract access token from the response
    access_token = response.json().get('access_token')
    instance_url = response.json().get('instance_url')

    # Authenticate to Salesforce using the access token
    sf = Salesforce(instance_url=instance_url, session_id=access_token)
    return sf

def get_object_fields(sf, object_name):
    object_metadata = sf.__getattr__(object_name).describe()
    fields = {field['name']: field for field in object_metadata['fields']}
    return fields

def find_common_fields(object1_fields, object2_fields):
    common_fields = set(object1_fields.keys()).intersection(set(object2_fields.keys()))
    return list(common_fields)

def find_reference_fields(object_fields, reference_to_object):
    reference_fields = [field['name'] for field in object_fields.values()
                        if 'referenceTo' in field and reference_to_object in field['referenceTo']]
    return reference_fields

def get_joinable_fields(object1, object2):
    sf = get_salesforce_session()

    # Get fields for both objects
    object1_fields = get_object_fields(sf, object1)
    object2_fields = get_object_fields(sf, object2)

    # Find common fields by name
    common_fields = find_common_fields(object1_fields, object2_fields)

    # Find reference fields
    object1_references_to_object2 = find_reference_fields(object1_fields, object2)
    object2_references_to_object1 = find_reference_fields(object2_fields, object1)

    # Create DataFrame
    data = {
        'Common Fields': common_fields,
        f'{object1} References {object2}': object1_references_to_object2,
        f'{object2} References {object1}': object2_references_to_object1
    }

    # Since the length of lists can differ, creating DataFrame in this way might lead to NaN values for mismatched lengths
    max_len = max(len(common_fields), len(object1_references_to_object2), len(object2_references_to_object1))
    for key in data:
        data[key] += [None] * (max_len - len(data[key]))  # Fill shorter lists with None

    df = pd.DataFrame(data)
    return df

# Example usage
object1 = 'pba__Closing__c'
object2 = 'pba__Listing__c'
joinable_fields_df = get_joinable_fields(object1, object2)
joinable_fields_df
# Out:
#                               Common Fields  \
# 0                          LastModifiedDate
# 1            Joint_Agency_Calculated_Fee__c
# 2                    Organisation_Domain__c
# 3                                MB_logo__c
# 4                     Current_User_Email__c
# 5                                    EPC__c
# 6                                   OwnerId
# 7                          LastModifiedById
# 8                         Rewards_Lister__c
# 9                         Calculated_Fee__c
# 10                                     Name
# 11                     Current_User_Name__c
# 12                                IsDeleted
# 13                        Vendor_Manager__c
# 14                   Lister_Name_Formula__c
# 15                     Pod_Match_Formula__c
# 16            MB_Property_Ombudsman_logo__c
# 17                           LastViewedDate
# 18                             RecordTypeId
# 19              Property_Owner_Household__c
# 20                      Record_Type_Name__c
# 21                    Current_User_Phone__c
# 22                         LastActivityDate
# 23                                Office__c
# 24                          Exchange_Fee__c
# 25                              CreatedById
# 26                              CreatedDate
# 27                           SystemModstamp
# 28                                   Pod__c
# 29                           Lister_Name__c
# 30                          CurrencyIsoCode
# 31                               EM_logo__c
# 32                       LastReferencedDate
# 33                           Todays_date__c
# 34  EM_Openworks_Property_Ombudsman_logo__c
# 35                             Entry_Fee__c
# 36             Solicitor_Referred_By_Who__c
# 37                                       Id
# 38                Success_Fee_To_Be_Paid__c
#
#    pba__Closing__c References pba__Listing__c  \
# 0                             pba__Listing__c
# 1                                        None
# 2                                        None
# 3                                        None
# 4                                        None
# 5                                        None
# 6                                        None
# 7                                        None
# 8                                        None
# 9                                        None
# 10                                       None
# 11                                       None
# 12                                       None
# 13                                       None
# 14                                       None
# 15                                       None
# 16                                       None
# 17                                       None
# 18                                       None
# 19                                       None
# 20                                       None
# 21                                       None
# 22                                       None
# 23                                       None
# 24                                       None
# 25                                       None
# 26                                       None
# 27                                       None
# 28                                       None
# 29                                       None
# 30                                       None
# 31                                       None
# 32                                       None
# 33                                       None
# 34                                       None
# 35                                       None
# 36                                       None
# 37                                       None
# 38                                       None
#
#    pba__Listing__c References pba__Closing__c
# 0                                        None
# 1                                        None
# 2                                        None
# 3                                        None
# 4                                        None
# 5                                        None
# 6                                        None
# 7                                        None
# 8                                        None
# 9                                        None
# 10                                       None
# 11                                       None
# 12                                       None
# 13                                       None
# 14                                       None
# 15                                       None
# 16                                       None
# 17                                       None
# 18                                       None
# 19                                       None
# 20                                       None
# 21                                       None
# 22                                       None
# 23                                       None
# 24                                       None
# 25                                       None
# 26                                       None
# 27                                       None
# 28                                       None
# 29                                       None
# 30                                       None
# 31                                       None
# 32                                       None
# 33                                       None
# 34                                       None
# 35                                       None
# 36                                       None
# 37                                       None
# 38                                       None

# %% [markdown]
# ### Formula Finder

# %%
import requests
import keyring

def get_salesforce_formula(object_name, field_name):
    # Retrieve your credentials
    username = keyring.get_password("salesforce", "username")
    password = keyring.get_password("salesforce", "password")
    security_token = keyring.get_password("salesforce", "security_token")
    consumer_key = keyring.get_password("salesforce", "consumer_key")
    consumer_secret = keyring.get_password("salesforce", "consumer_secret")

    # Step 1: Obtain OAuth 2.0 token
    token_url = "https://login.salesforce.com/services/oauth2/token"
    payload = {
        'grant_type': 'password',
        'client_id': consumer_key,
        'client_secret': consumer_secret,
        'username': username,
        'password': password + security_token
    }
    response = requests.post(token_url, data=payload)
    response.raise_for_status()  # Check if the request was successful

    # Extract access token from the response
    access_token = response.json().get('access_token')
    instance_url = response.json().get('instance_url')

    # Step 2: Retrieve object metadata
    headers = {
        'Authorization': f'Bearer {access_token}',
        'Content-Type': 'application/json'
    }
    metadata_url = f"{instance_url}/services/data/v52.0/sobjects/{object_name}/describe"
    metadata_response = requests.get(metadata_url, headers=headers)
    metadata_response.raise_for_status()  # Check if the request was successful
    metadata = metadata_response.json()

    # Step 3: Find the specific field and extract its formula
    formula = None
    for field in metadata['fields']:
        if field['name'] == field_name:
            if field.get('calculated') and field.get('calculatedFormula'):
                formula = field['calculatedFormula']
            else:
                formula = "The specified field is not a calculated field."
            break
    else:
        formula = "Field not found in the specified object."

    return formula

# Example usage
object_name = 'OPPORTUNITY'
field_name = 'OPPORTUNITY_NAME'
formula = get_salesforce_formula(object_name, field_name)
print(f"Field: {field_name}, Formula: {formula}")
# Out:
# Field: OPPORTUNITY_NAME, Formula: Field not found in the specified object.

# %% [markdown]
# ### Get the table or sample

# %%
import requests
import pandas as pd
from simple_salesforce import Salesforce
import keyring
import sweetviz

def export_salesforce_data(object_name, record_limit=None):
    # Retrieve your credentials
    username = keyring.get_password("salesforce", "username")
    password = keyring.get_password("salesforce", "password")
    security_token = keyring.get_password("salesforce", "security_token")
    consumer_key = keyring.get_password("salesforce", "consumer_key")
    consumer_secret = keyring.get_password("salesforce", "consumer_secret")

    # Step 1: Obtain OAuth 2.0 token
    token_url = "https://login.salesforce.com/services/oauth2/token"
    payload = {
        'grant_type': 'password',
        'client_id': consumer_key,
        'client_secret': consumer_secret,
        'username': username,
        'password': password + security_token
    }
    response = requests.post(token_url, data=payload)
    response.raise_for_status()  # Check if the request was successful

    # Extract access token from the response
    access_token = response.json().get('access_token')
    instance_url = response.json().get('instance_url')

    # Step 2: Authenticate to Salesforce using the access token
    sf = Salesforce(instance_url=instance_url, session_id=access_token)

    # Step 3: Retrieve object metadata to get all column names
    object_metadata = sf.__getattr__(object_name).describe()
    column_names = [field['name'] for field in object_metadata['fields']]

    # Construct SOQL query to get all data from the object
    query = f"SELECT {', '.join(column_names)} FROM {object_name}"
    if record_limit:
        query += f" LIMIT {record_limit}"

    # Step 4: Query data
    records = []
    query_result = sf.query_all(query)
    records.extend(query_result['records'])

    # Continue querying if there are more records and no limit was set
    while not query_result['done'] and not record_limit:
        query_result = sf.query_more(query_result['nextRecordsUrl'], True)
        records.extend(query_result['records'])

    # Convert the data to a pandas DataFrame
    df = pd.DataFrame(records)

    # Clean up the DataFrame (remove Salesforce metadata)
    if 'attributes' in df.columns:
        df = df.drop(columns=['attributes'])

    return df

# Example usage
object_name = 'pba__Offer__c'
#record_limit = 5000  # Set to None to retrieve all records
df = export_salesforce_data(object_name, record_limit=None)
df

# Generate Sweetviz report
# report = sweetviz.analyze(df)
# report.show_html('report.html')

# You can now analyze the DataFrame df as needed
# print(df.head())
# Out:
#                        Id             OwnerId  IsDeleted      Name  \
# 0      a0G3t00000HCjlzEAD  0053t000006YrbuAAC      False  O-003209
# 1      a0G3t00000HCl3KEAT  0053t000008UnS3AAK      False  O-007128
# 2      a0G3t00000HCl3LEAT  0053t000008UnRzAAK      False  O-007129
# 3      a0G3t00000HCl3MEAT  0053t000008UnRUAA0      False  O-007130
# 4      a0G3t00000HCl3NEAT  0053t000008UnRUAA0      False  O-007131
# ...                   ...                 ...        ...       ...
# 34892  a0GWS000000UnHp2AK  0053t000008UnRyAAK      False  O-050094
# 34893  a0GWS000000UnuX2AS  0053t000008t2DCAAY      False  O-050095
# 34894  a0GWS000000Uo0z2AC  0058W00000CWfZ9QAL      False  O-050096
# 34895  a0GWS000000UoNZ2A0  0058W00000FilU7QAJ      False  O-050097
# 34896  a0GWS000000UoQn2AK  0058W00000FilU7QAJ      False  O-050098
#
#       CurrencyIsoCode        RecordTypeId                   CreatedDate  \
# 0                 GBP  0123t000000NWcbAAG  2021-02-16T12:11:48.000+0000
# 1                 GBP  0123t000000NWcbAAG  2021-02-15T16:46:00.000+0000
# 2                 GBP  0123t000000NWcbAAG  2021-02-15T16:28:00.000+0000
# 3                 GBP  0123t000000NWcbAAG  2021-02-15T16:16:00.000+0000
# 4                 GBP  0123t000000NWcbAAG  2021-02-15T14:45:00.000+0000
# ...               ...                 ...                           ...
# 34892             GBP  0123t000000GDXVAA4  2024-07-24T16:15:24.000+0000
# 34893             GBP  0123t000000NWcbAAG  2024-07-25T07:33:53.000+0000
# 34894             GBP  0123t000000NWcbAAG  2024-07-25T08:55:29.000+0000
# 34895             GBP  0123t000000Akl8AAC  2024-07-25T09:54:35.000+0000
# 34896             GBP  0123t000000NWcbAAG  2024-07-25T10:00:06.000+0000
#
#               CreatedById              LastModifiedDate    LastModifiedById  \
# 0      0053t000006YrbuAAC  2024-05-21T09:14:55.000+0000  0053t000008Udn5AAC
# 1      0053t000008UbxuAAC  2021-02-16T17:43:55.000+0000  0053t000008UbxuAAC
# 2      0053t000008UbxuAAC  2021-02-16T17:43:55.000+0000  0053t000008UbxuAAC
# 3      0053t000008UbxuAAC  2021-02-16T17:43:55.000+0000  0053t000008UbxuAAC
# 4      0053t000008UbxuAAC  2021-02-16T17:43:55.000+0000  0053t000008UbxuAAC
# ...                   ...                           ...                 ...
# 34892  0053t000008t8wgAAA  2024-07-24T16:16:07.000+0000  0053t000008t8wgAAA
# 34893  0053t000008t2DCAAY  2024-07-25T07:35:15.000+0000  0053t000008t2DCAAY
# 34894  0058W00000CWfZ9QAL  2024-07-25T10:29:13.000+0000  0053t000008UnRMAA0
# 34895  0058W00000FilU7QAJ  2024-07-25T09:55:10.000+0000  0058W00000FilU7QAJ
# 34896  0058W00000FilU7QAJ  2024-07-25T10:00:17.000+0000  0058W00000FilU7QAJ
#
#        ... Offer_Notes_2__c Offer_Notes_3__c Offer_Notes_4__c  \
# 0      ...             None             None             None
# 1      ...             None             None             None
# 2      ...             None             None             None
# 3      ...             None             None             None
# 4      ...             None             None             None
# ...    ...              ...              ...              ...
# 34892  ...             None             None             None
# 34893  ...             None             None             None
# 34894  ...             None             None             None
# 34895  ...             None             None             None
# 34896  ...             None             None             None
#
#       Offer_Notes_5__c Offer_Notes_6__c Offer_Notes_7__c Offer_Notes_8__c  \
# 0                 None             None             None             None
# 1                 None             None             None             None
# 2                 None             None             None             None
# 3                 None             None             None             None
# 4                 None             None             None             None
# ...                ...              ...              ...              ...
# 34892             None             None             None             None
# 34893             None             None             None             None
# 34894             None             None             None             None
# 34895             None             None             None             None
# 34896             None             None             None             None
#
#       Offer_Notes_9__c Offer_Notes_10__c Organisation_Domain__c
# 0                 None              None                   None
# 1                 None              None                   None
# 2                 None              None                   None
# 3                 None              None                   None
# 4                 None              None                   None
# ...                ...               ...                    ...
# 34892             None              None                   None
# 34893             None              None                   None
# 34894             None              None                   None
# 34895             None              None                   None
# 34896             None              None                   None
#
# [34897 rows x 154 columns]

# %%
df.to_csv('Offer.csv')

# %% [markdown]
# ## Table extractor with query

# %%
import requests
import pandas as pd
from simple_salesforce import Salesforce
import keyring

def export_salesforce_data(query, export_file):
    # Retrieve your credentials
    username = keyring.get_password("salesforce", "username")
    password = keyring.get_password("salesforce", "password")
    security_token = keyring.get_password("salesforce", "security_token")
    consumer_key = keyring.get_password("salesforce", "consumer_key")
    consumer_secret = keyring.get_password("salesforce", "consumer_secret")

    # Step 1: Obtain OAuth 2.0 token
    token_url = "https://login.salesforce.com/services/oauth2/token"
    payload = {
        'grant_type': 'password',
        'client_id': consumer_key,
        'client_secret': consumer_secret,
        'username': username,
        'password': password + security_token
    }
    response = requests.post(token_url, data=payload)
    response.raise_for_status()  # Check if the request was successful

    # Extract access token from the response
    access_token = response.json().get('access_token')
    instance_url = response.json().get('instance_url')

    # Step 2: Authenticate to Salesforce using the access token
    sf = Salesforce(instance_url=instance_url, session_id=access_token)

    # Step 3: Query data
    records = []
    query_result = sf.query_all(query)
    records.extend(query_result['records'])

    # Continue querying if there are more records
    while not query_result['done']:
        query_result = sf.query_more(query_result['nextRecordsUrl'], True)
        records.extend(query_result['records'])

    # Convert the data to a pandas DataFrame
    df = pd.DataFrame(records)

    # Clean up the DataFrame (remove Salesforce metadata)
    if 'attributes' in df.columns:
        df = df.drop(columns=['attributes'])

    # Export the DataFrame to a CSV file
    df.to_csv(export_file, index=False)
    print(f"Data exported to {export_file}")

# Example usage
query = """
SELECT 




User__c, 
Name, 
Primary__r.Name,
Role_Title__r.Name  






from Staff__c
"""
export_file = 'test.csv'

export_salesforce_data(query, export_file)
# Out:
# Data exported to test.csv

# %% [markdown]
# ## Table extractor or sample

# %%
import requests
import pandas as pd
from simple_salesforce import Salesforce
import keyring
import sweetviz

def export_salesforce_data(object_name, record_limit=None):
    # Retrieve your credentials
    username = keyring.get_password("salesforce", "username")
    password = keyring.get_password("salesforce", "password")
    security_token = keyring.get_password("salesforce", "security_token")
    consumer_key = keyring.get_password("salesforce", "consumer_key")
    consumer_secret = keyring.get_password("salesforce", "consumer_secret")

    # Step 1: Obtain OAuth 2.0 token
    token_url = "https://login.salesforce.com/services/oauth2/token"
    payload = {
        'grant_type': 'password',
        'client_id': consumer_key,
        'client_secret': consumer_secret,
        'username': username,
        'password': password + security_token
    }
    response = requests.post(token_url, data=payload)
    response.raise_for_status()  # Check if the request was successful

    # Extract access token from the response
    access_token = response.json().get('access_token')
    instance_url = response.json().get('instance_url')

    # Step 2: Authenticate to Salesforce using the access token
    sf = Salesforce(instance_url=instance_url, session_id=access_token)

    # Step 3: Retrieve object metadata to get all column names
    object_metadata = sf.__getattr__(object_name).describe()
    column_names = [field['name'] for field in object_metadata['fields']]

    # Construct SOQL query to get all data from the object
    query = f"SELECT {', '.join(column_names)} FROM {object_name}"
    if record_limit:
        query += f" LIMIT {record_limit}"

    # Step 4: Query data
    records = []
    query_result = sf.query_all(query)
    records.extend(query_result['records'])

    # Continue querying if there are more records and no limit was set
    while not query_result['done'] and not record_limit:
        query_result = sf.query_more(query_result['nextRecordsUrl'], True)
        records.extend(query_result['records'])

    # Convert the data to a pandas DataFrame
    df = pd.DataFrame(records)

    # Clean up the DataFrame (remove Salesforce metadata)
    if 'attributes' in df.columns:
        df = df.drop(columns=['attributes'])

    return df

# Example usage
object_name = 'Staff__c'
#record_limit = 5000  # Set to None to retrieve all records
df = export_salesforce_data(object_name, record_limit=None)
df

# Generate Sweetviz report
# report = sweetviz.analyze(df)
# report.show_html('report.html')

# You can now analyze the DataFrame df as needed
# print(df.head())
# Out:
#                      Id  IsDeleted               Name CurrencyIsoCode  \
# 0    a3o8W000000jmbxQAA      False        Mehak Nazam             GBP
# 1    a3o8W000000jmc2QAA      False      Lindsay Heath             GBP
# 2    a3o8W000000jmc7QAA      False   Brooke Rushworth             GBP
# 3    a3o8W000000jmcRQAQ      False     Christian Vose             GBP
# 4    a3o8W000000jmcWQAQ      False  Issabella Chapman             GBP
# ..                  ...        ...                ...             ...
# 157  a3o8W000001vq4zQAA      False  Deepankar Srigyan             GBP
# 158  a3o8W000001vq54QAA      False     Grace Beaumont             GBP
# 159  a3oWS0000007UfhYAE      False    Catherine Dixon             GBP
# 160  a3oWS0000007VFBYA2      False     Stephen Hankey             GBP
# 161  a3oWS0000007cq9YAA      False      Findlay Kelly             GBP
#
#                       CreatedDate         CreatedById  \
# 0    2023-10-19T14:16:26.000+0000  0058W00000BZQ4dQAH
# 1    2023-10-19T16:21:26.000+0000  0053t000008Udn5AAC
# 2    2023-10-25T14:56:15.000+0000  0053t000008Udn5AAC
# 3    2023-10-31T17:01:44.000+0000  0053t000008Udn5AAC
# 4    2023-11-01T15:24:04.000+0000  0053t000008Udn5AAC
# ..                            ...                 ...
# 157  2024-07-15T09:11:31.000+0000  0058W00000BZQ4dQAH
# 158  2024-07-16T14:41:01.000+0000  0058W00000BZQ4dQAH
# 159  2024-07-23T10:49:29.000+0000  0058W00000BZQ4dQAH
# 160  2024-07-25T11:23:59.000+0000  0053t000008Udn5AAC
# 161  2024-08-09T14:03:25.000+0000  0053t000008Udn5AAC
#
#                  LastModifiedDate    LastModifiedById  \
# 0    2024-08-08T15:51:19.000+0000  0058W00000BZQ4dQAH
# 1    2024-08-08T15:51:19.000+0000  0058W00000BZQ4dQAH
# 2    2023-10-25T14:56:15.000+0000  0053t000008Udn5AAC
# 3    2024-08-08T15:51:19.000+0000  0058W00000BZQ4dQAH
# 4    2023-11-22T16:55:27.000+0000  0058W00000BZQ4dQAH
# ..                            ...                 ...
# 157  2024-08-08T15:51:19.000+0000  0058W00000BZQ4dQAH
# 158  2024-08-08T15:51:19.000+0000  0058W00000BZQ4dQAH
# 159  2024-07-23T13:12:07.000+0000  0058W00000BZQ4dQAH
# 160  2024-08-08T15:51:19.000+0000  0058W00000BZQ4dQAH
# 161  2024-08-09T16:02:25.000+0000  0053t000008Udn5AAC
#
#                    SystemModstamp LastViewedDate  ... VCCSSOExtID__c  \
# 0    2024-08-08T15:51:19.000+0000           None  ...           None
# 1    2024-08-08T15:51:19.000+0000           None  ...           None
# 2    2023-10-25T14:56:15.000+0000           None  ...           None
# 3    2024-08-08T15:51:19.000+0000           None  ...           None
# 4    2023-12-08T07:31:04.000+0000           None  ...           None
# ..                            ...            ...  ...            ...
# 157  2024-08-08T15:51:19.000+0000           None  ...           None
# 158  2024-08-08T15:51:19.000+0000           None  ...           None
# 159  2024-07-23T13:12:07.000+0000           None  ...           None
# 160  2024-08-08T15:51:19.000+0000           None  ...           None
# 161  2024-08-09T16:02:25.000+0000           None  ...           None
#
#     VCCIn_Country_Display__c                        VCCUsername__c  \
# 0                   National        mehak.nazam@edwardmellor.co.uk
# 1                   National      lindsay.heath@edwardmellor.co.uk
# 2                       None       brookejaydenrushworth@gmail.com
# 3                   National     christian.vose@edwardmellor.co.uk
# 4                   National  issabella.chapman@edwardmellor.co.uk
# ..                       ...                                   ...
# 157                     None  deepankar.srigyan@edwardmellor.co.uk
# 158                 National     grace.beaumont@edwardmellor.co.uk
# 159                     None                                  None
# 160                     None                stephenjh.71@gmail.com
# 161                     None      findlay.kelly@edwardmellor.co.uk
#
#     VCC_NvmAgentID__c VCCCallback_Numbers__c         VCCName__c  \
# 0                1086                   None        Mehak Nazam
# 1                1079                   None      Lindsay Heath
# 2                None                   None   Brooke Rushworth
# 3                1034                   None     Christian Vose
# 4                1066                   None  Issabella Chapman
# ..                ...                    ...                ...
# 157              1141           441614434511  Deepankar Srigyan
# 158              1142                   None     Grace Beaumont
# 159              1136                   None    Catherine Dixon
# 160              None                   None     Stephen Hankey
# 161              1143                   None      Findlay Kelly
#
#     VCC_Divert_Number__c JANUS_Email_all_Updates__c      Office_Name__c  \
# 0                   None                      False  Financial Services
# 1                   None                      False  Financial Services
# 2                   None                      False     To Be Completed
# 3                   None                      False           Droylsden
# 4                   None                      False             Auction
# ..                   ...                        ...                 ...
# 157                 None                      False         Head Office
# 158                 None                      False         Head Office
# 159        +447935115340                      False         Head Office
# 160                 None                      False              Marple
# 161                 None                      False         Hazel Grove
#
#                POD_Name__c
# 0       Financial Services
# 1       Financial Services
# 2                     None
# 3       Droylsden & Gorton
# 4                  Auction
# ..                     ...
# 157            Head Office
# 158            Head Office
# 159            Head Office
# 160       Woodley & Marple
# 161  Hazel Grove & Edgeley
#
# [162 rows x 49 columns]

# %%
df.to_csv('Offer.csv')

# %% [markdown]
# ### dataset profile

# %%
import dtale
import sweetviz

# %%
df.dtypes
# Out:
# Id                                                  object
# Username                                            object
# LastName                                            object
# FirstName                                           object
# Name                                                object
#                                                      ...
# NVMContactWorld__MostRecentCallEventTimestamp__c    object
# NVMContactWorld__MostRecentCallIsActive__c            bool
# NVMContactWorld__MostRecentCall__c                  object
# NVMContactWorld__NVM_Agent_Id__c                    object
# NVMContactWorld__NotesCollapsed__c                    bool
# Length: 254, dtype: object

# %%
def convert_complex_to_string(value):
    if isinstance(value, (dict, list, set)):
        return str(value)
    return value

# Apply the function to the entire DataFrame
df = df.map(convert_complex_to_string)

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
user_report  = sweetviz.analyze(df)
user_report.show_html('user_report.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# PAIRWISE CALCULATION LENGTH WARNING: There are 254 features in this dataframe and the 'pairwise_analysis' parameter is set to 'auto'.
# Pairwise analysis is exponential in length: 254 features will cause ~64516 pairs to be evaluated, which could take a long time.
#
# You must call the function with the parameter pairwise_analysis='on' or 'off' to explicitly select desired behavior.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 2
#       1 user_report  = sweetviz.analyze(df)
# ----> 2 user_report.show_html('user_report.html')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sweetviz\dataframe_report.py:549, in DataframeReport.show_html(self, filepath, open_browser, layout, scale)
#     547 sv_html.set_summary_positions(self)
#     548 sv_html.generate_html_detail(self)
# --> 549 if self.associations_html_source:
#     550     self.associations_html_source = sv_html.generate_html_associations(self, "source")
#     551 if self.associations_html_compare:
#
# AttributeError: 'DataframeReport' object has no attribute 'associations_html_source'

# %% [markdown]
# ## All Formula in an object

# %%
import requests
import pandas as pd
import keyring

def get_salesforce_formulas(object_name):
    # Retrieve your credentials
    username = keyring.get_password("salesforce", "username")
    password = keyring.get_password("salesforce", "password")
    security_token = keyring.get_password("salesforce", "security_token")
    consumer_key = keyring.get_password("salesforce", "consumer_key")
    consumer_secret = keyring.get_password("salesforce", "consumer_secret")

    # Step 1: Obtain OAuth 2.0 token
    token_url = "https://login.salesforce.com/services/oauth2/token"
    payload = {
        'grant_type': 'password',
        'client_id': consumer_key,
        'client_secret': consumer_secret,
        'username': username,
        'password': password + security_token
    }
    response = requests.post(token_url, data=payload)
    response.raise_for_status()  # Check if the request was successful

    # Extract access token from the response
    access_token = response.json().get('access_token')
    instance_url = response.json().get('instance_url')

    # Step 2: Retrieve object metadata
    headers = {
        'Authorization': f'Bearer {access_token}',
        'Content-Type': 'application/json'
    }
    metadata_url = f"{instance_url}/services/data/v52.0/sobjects/{object_name}/describe"
    metadata_response = requests.get(metadata_url, headers=headers)
    metadata_response.raise_for_status()  # Check if the request was successful
    metadata = metadata_response.json()

    # Step 3: Extract formulas for custom fields
    formulas = []
    for field in metadata['fields']:
        if field.get('calculated'):
            formulas.append({
                'Field Name': field['name'],
                'Formula': field.get('calculatedFormula')
            })

    # Convert the list of formulas to a pandas DataFrame
    df = pd.DataFrame(formulas)
    return df

# Example usage
object_name = 'User'
formulas_df = get_salesforce_formulas(object_name)
formulas_df
# Out:
#                   Field Name  \
# 0            License_Type__c
# 1  lightico__Profile_Name__c
# 2     lightico__Role_Name__c
# 3        Profile_Dev_Name__c
# 4           Role_Dev_Name__c
# 5    Viewing_Offices_Text__c
# 6            Staff_Record__c
#
#                                              Formula
# 0                           Profile.UserLicense.Name
# 1  IF(TRIM(Profile.Name) = 'PT1', 'System Adminis...
# 2                                      UserRole.Name
# 3                                       Profile.Name
# 4                                      UserRole.Name
# 5  Text(POD__c) &";"&Text(Office__c)&";"&\r\nIF (...
# 6  IF(ISBLANK(Staff_Record_ID__c),"Building Staff...

# %%
formulas_df.to_excel('user_formula.xlsx')

# %% [markdown]
# ## Formula for specific Field

# %%
import requests
import keyring

def get_salesforce_formula(object_name, field_name):
    # Retrieve your credentials
    username = keyring.get_password("salesforce", "username")
    password = keyring.get_password("salesforce", "password")
    security_token = keyring.get_password("salesforce", "security_token")
    consumer_key = keyring.get_password("salesforce", "consumer_key")
    consumer_secret = keyring.get_password("salesforce", "consumer_secret")

    # Step 1: Obtain OAuth 2.0 token
    token_url = "https://login.salesforce.com/services/oauth2/token"
    payload = {
        'grant_type': 'password',
        'client_id': consumer_key,
        'client_secret': consumer_secret,
        'username': username,
        'password': password + security_token
    }
    response = requests.post(token_url, data=payload)
    response.raise_for_status()  # Check if the request was successful

    # Extract access token from the response
    access_token = response.json().get('access_token')
    instance_url = response.json().get('instance_url')

    # Step 2: Retrieve object metadata
    headers = {
        'Authorization': f'Bearer {access_token}',
        'Content-Type': 'application/json'
    }
    metadata_url = f"{instance_url}/services/data/v52.0/sobjects/{object_name}/describe"
    metadata_response = requests.get(metadata_url, headers=headers)
    metadata_response.raise_for_status()  # Check if the request was successful
    metadata = metadata_response.json()

    # Step 3: Find the specific field and extract its formula
    formula = None
    for field in metadata['fields']:
        if field['name'] == field_name:
            if field.get('calculated') and field.get('calculatedFormula'):
                formula = field['calculatedFormula']
            else:
                formula = "The specified field is not a calculated field."
            break
    else:
        formula = "Field not found in the specified object."

    return formula

# Example usage
object_name = 'Contact'
field_name = 'Mortgage_Referred_By_Who__c'
formula = get_salesforce_formula(object_name, field_name)
print(f"Field: {field_name}, Formula: {formula}")
# Out:
# Field: Mortgage_Referred_By_Who__c, Formula: The specified field is not a calculated field.

# %%
import requests
import pandas as pd
from simple_salesforce import Salesforce
import keyring

def export_salesforce_data(query, export_file):
    # Retrieve your credentials
    username = keyring.get_password("salesforce", "username")
    password = keyring.get_password("salesforce", "password")
    security_token = keyring.get_password("salesforce", "security_token")
    consumer_key = keyring.get_password("salesforce", "consumer_key")
    consumer_secret = keyring.get_password("salesforce", "consumer_secret")

    # Step 1: Obtain OAuth 2.0 token
    token_url = "https://login.salesforce.com/services/oauth2/token"
    payload = {
        'grant_type': 'password',
        'client_id': consumer_key,
        'client_secret': consumer_secret,
        'username': username,
        'password': password + security_token
    }
    response = requests.post(token_url, data=payload)
    response.raise_for_status()  # Check if the request was successful

    # Extract access token from the response
    access_token = response.json().get('access_token')
    instance_url = response.json().get('instance_url')

    # Step 2: Authenticate to Salesforce using the access token
    sf = Salesforce(instance_url=instance_url, session_id=access_token)

    # Step 3: Query data
    records = []
    query_result = sf.query_all(query)
    records.extend(query_result['records'])

    # Continue querying if there are more records
    while not query_result['done']:
        query_result = sf.query_more(query_result['nextRecordsUrl'], True)
        records.extend(query_result['records'])

    # Function to flatten nested dictionaries
    def flatten_record(record, parent_key='', sep='.'):
        items = []
        for k, v in record.items():
            new_key = f"{parent_key}{sep}{k}" if parent_key else k
            if isinstance(v, dict):
                items.extend(flatten_record(v, new_key, sep=sep).items())
            else:
                items.append((new_key, v))
        return dict(items)

    # Flatten all records
    flattened_records = [flatten_record(record) for record in records]

    # Convert the data to a pandas DataFrame
    df = pd.DataFrame(flattened_records)

    # Clean up the DataFrame (remove Salesforce metadata)
    if 'attributes.type' in df.columns:
        df = df.drop(columns=['attributes.type', 'attributes.url'])

    # Display the DataFrame
    return df

# Example usage
query = """
SELECT
    User__c, 
    Name, 
    Primary__r.Name,
    Primary__r.POD__r.Name,
    Role_Title__r.Name  
FROM
    Staff__c
"""
export_file = 'test.csv'

# Get the DataFrame
df = export_salesforce_data(query, export_file)

# Display the DataFrame
df

# Optionally, export the DataFrame to a CSV file
df.to_csv(export_file, index=False)
print(f"Data exported to {export_file}")
# Out:
# Data exported to test.csv

# %%
df
# Out:
#                 User__c               Name Primary__r.attributes.type  \
# 0    0058W00000EKrpxQAD        Mehak Nazam             pba__Office__c
# 1    0058W00000EKsUHQA1      Lindsay Heath             pba__Office__c
# 2    0058W00000ELDWxQAP   Brooke Rushworth             pba__Office__c
# 3    0058W00000ELWtIQAX     Christian Vose             pba__Office__c
# 4    0058W00000ELYo4QAH  Issabella Chapman             pba__Office__c
# ..                  ...                ...                        ...
# 156  0058W00000GGiruQAD      Megan Edwards             pba__Office__c
# 157  0058W00000GHExkQAH  Deepankar Srigyan             pba__Office__c
# 158  0058W00000GHGGYQA5     Grace Beaumont             pba__Office__c
# 159                None    Catherine Dixon             pba__Office__c
# 160  005WS000000zZKDYA2     Stephen Hankey             pba__Office__c
#
#                              Primary__r.attributes.url     Primary__r.Name  \
# 0    /services/data/v59.0/sobjects/pba__Office__c/a...  Financial Services
# 1    /services/data/v59.0/sobjects/pba__Office__c/a...  Financial Services
# 2    /services/data/v59.0/sobjects/pba__Office__c/a...     To Be Completed
# 3    /services/data/v59.0/sobjects/pba__Office__c/a...           Droylsden
# 4    /services/data/v59.0/sobjects/pba__Office__c/a...             Auction
# ..                                                 ...                 ...
# 156  /services/data/v59.0/sobjects/pba__Office__c/a...      Stockton Heath
# 157  /services/data/v59.0/sobjects/pba__Office__c/a...         Head Office
# 158  /services/data/v59.0/sobjects/pba__Office__c/a...         Head Office
# 159  /services/data/v59.0/sobjects/pba__Office__c/a...         Head Office
# 160  /services/data/v59.0/sobjects/pba__Office__c/a...              Marple
#
#     Primary__r.POD__r.attributes.type  \
# 0                     POD_Grouping__c
# 1                     POD_Grouping__c
# 2                                 NaN
# 3                     POD_Grouping__c
# 4                     POD_Grouping__c
# ..                                ...
# 156                   POD_Grouping__c
# 157                   POD_Grouping__c
# 158                   POD_Grouping__c
# 159                   POD_Grouping__c
# 160                   POD_Grouping__c
#
#                       Primary__r.POD__r.attributes.url  \
# 0    /services/data/v59.0/sobjects/POD_Grouping__c/...
# 1    /services/data/v59.0/sobjects/POD_Grouping__c/...
# 2                                                  NaN
# 3    /services/data/v59.0/sobjects/POD_Grouping__c/...
# 4    /services/data/v59.0/sobjects/POD_Grouping__c/...
# ..                                                 ...
# 156  /services/data/v59.0/sobjects/POD_Grouping__c/...
# 157  /services/data/v59.0/sobjects/POD_Grouping__c/...
# 158  /services/data/v59.0/sobjects/POD_Grouping__c/...
# 159  /services/data/v59.0/sobjects/POD_Grouping__c/...
# 160  /services/data/v59.0/sobjects/POD_Grouping__c/...
#
#                     Primary__r.POD__r.Name Role_Title__r.attributes.type  \
# 0                       Financial Services                       Role__c
# 1                       Financial Services                       Role__c
# 2                                      NaN                           NaN
# 3                       Droylsden & Gorton                       Role__c
# 4                                  Auction                       Role__c
# ..                                     ...                           ...
# 156  Cheshire (Stockton Heath & Northwich)                           NaN
# 157                            Head Office                       Role__c
# 158                            Head Office                       Role__c
# 159                            Head Office                           NaN
# 160                       Woodley & Marple                           NaN
#
#                           Role_Title__r.attributes.url  \
# 0    /services/data/v59.0/sobjects/Role__c/a4m8W000...
# 1    /services/data/v59.0/sobjects/Role__c/a4m8W000...
# 2                                                  NaN
# 3    /services/data/v59.0/sobjects/Role__c/a4m8W000...
# 4    /services/data/v59.0/sobjects/Role__c/a4m8W000...
# ..                                                 ...
# 156                                                NaN
# 157  /services/data/v59.0/sobjects/Role__c/a4m8W000...
# 158  /services/data/v59.0/sobjects/Role__c/a4m8W000...
# 159                                                NaN
# 160                                                NaN
#
#                 Role_Title__r.Name  Primary__r.POD__r  Role_Title__r
# 0             Relationship Manager                NaN            NaN
# 1    Mortgage & Protection Advisor                NaN            NaN
# 2                              NaN                NaN            NaN
# 3                 Sales Progressor                NaN            NaN
# 4               Auction Consultant                NaN            NaN
# ..                             ...                ...            ...
# 156                            NaN                NaN            NaN
# 157                   Data Analyst                NaN            NaN
# 158       Group Operations Manager                NaN            NaN
# 159                            NaN                NaN            NaN
# 160                            NaN                NaN            NaN
#
# [161 rows x 13 columns]
